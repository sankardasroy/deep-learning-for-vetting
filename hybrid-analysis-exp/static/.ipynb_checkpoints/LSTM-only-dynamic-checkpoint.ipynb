# %%
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from keras.preprocessing.text import Tokenizer
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.preprocessing import sequence
from keras.datasets import imdb
from keras.models import Sequential,load_model
from keras.layers import Embedding,Dense,Flatten
#from keras.models import load_model
import numpy as np
import os,sys
import math
input_path = "/home/ubuntu/static_mixed"
word2vec_model = KeyedVectors.load("/home/ubuntu/first.model", mmap='r')
# Out:
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# !conda update --all
# Out:
# Solving environment: |
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults::libgfortran-3.0.0-1
#   - conda-forge::libgfortran-3.0.0done
#
# ## Package Plan ##
#
#   environment location: /home/ubuntu/anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports-1.0              |             py_2         139 KB
#     notebook-6.0.2             |           py36_0         6.3 MB
#     ipykernel-5.1.3            |   py36h39e3cac_0         167 KB
#     partd-1.1.0                |             py_0          20 KB
#     pylint-2.4.4               |           py36_0         434 KB
#     pyzmq-18.1.0               |   py36he6710b0_0         520 KB
#     more-itertools-7.2.0       |           py36_0          99 KB
#     testpath-0.4.4             |             py_0          88 KB
#     lz4-c-1.8.1.2              |       h14c3975_0         158 KB
#     flask-cors-3.0.8           |             py_0          17 KB
#     xlsxwriter-1.2.6           |             py_0         107 KB
#     setuptools-42.0.1          |           py36_0         644 KB
#     path.py-12.0.2             |             py_0          23 KB
#     html5lib-1.0.1             |             py_0          89 KB
#     krb5-1.16.1                |       h173b8e3_7         1.4 MB
#     bottleneck-1.3.1           |   py36hdd07704_0         136 KB
#     urllib3-1.24.2             |           py36_0         153 KB
#     click-7.0                  |             py_0          64 KB
#     botocore-1.13.19           |             py_0         3.3 MB
#     six-1.13.0                 |           py36_0          27 KB
#     bkcharts-0.2               |           py36_0         127 KB
#     lxml-4.4.1                 |   py36hefd8a0e_0         1.6 MB
#     zstd-1.3.7                 |       h0b5b093_0         887 KB
#     imageio-2.6.1              |           py36_0         3.4 MB
#     wurlitzer-2.0.0            |           py36_0          14 KB
#     parso-0.5.1                |             py_0          68 KB
#     multipledispatch-0.6.0     |           py36_0          21 KB
#     msgpack-python-0.6.1       |   py36hfd86e86_1          92 KB
#     conda-package-handling-1.6.0|   py36h7b6447c_0         871 KB
#     pytables-3.6.1             |   py36h71ec239_0         1.5 MB
#     pytest-astropy-header-0.1.1|             py_0          11 KB
#     cytoolz-0.10.1             |   py36h7b6447c_0         437 KB
#     pygments-2.4.2             |             py_0         664 KB
#     pytest-openfiles-0.4.0     |             py_0          10 KB
#     ripgrep-0.10.0             |       hc07d326_0         1.4 MB
#     pycparser-2.19             |             py_0          89 KB
#     wrapt-1.11.2               |   py36h7b6447c_0          48 KB
#     alabaster-0.7.12           |             py_0          16 KB
#     scikit-image-0.15.0        |   py36he6710b0_0        28.4 MB
#     sphinxcontrib-1.0          |           py36_1           3 KB
#     libtool-2.4.6              |       h7b6447c_5         513 KB
#     blaze-0.11.3               |           py36_0         603 KB
#     cloudpickle-1.2.2          |             py_0          29 KB
#     packaging-19.2             |             py_0          30 KB
#     psutil-5.6.5               |   py36h7b6447c_0         329 KB
#     jupyterlab_launcher-0.13.1 |           py36_0          36 KB
#     pyrsistent-0.15.6          |   py36h7b6447c_0          93 KB
#     openpyxl-3.0.1             |             py_0         158 KB
#     sphinxcontrib-qthelp-1.0.2 |             py_0          26 KB
#     unicodecsv-0.14.1          |           py36_0          25 KB
#     pycurl-7.43.0.3            |   py36h1ba5d50_0          70 KB
#     smart_open-1.9.0           |             py_0          59 KB
#     glob2-0.7                  |             py_0          14 KB
#     pyparsing-2.4.5            |             py_0          62 KB
#     importlib_metadata-0.23    |           py36_0          43 KB
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     numba-0.46.0               |   py36h962f231_0         3.2 MB
#     webencodings-0.5.1         |           py36_1          19 KB
#     blosc-1.16.3               |       hd408876_0          82 KB
#     py-1.8.0                   |             py_0          66 KB
#     babel-2.7.0                |             py_0         5.8 MB
#     cffi-1.13.2                |   py36h2e261b9_0         224 KB
#     pluggy-0.13.1              |           py36_0          32 KB
#     jdcal-1.4.1                |             py_0          11 KB
#     mpc-1.1.0                  |       h10f8cd9_1          94 KB
#     sympy-1.4                  |           py36_0         9.7 MB
#     markupsafe-1.1.1           |   py36h7b6447c_0          29 KB
#     pykerberos-1.1.14          |   py36h84109d8_2          22 KB
#     pytz-2019.3                |             py_0         231 KB
#     werkzeug-0.16.0            |             py_0         255 KB
#     distributed-2.8.1          |             py_0         402 KB
#     entrypoints-0.3            |           py36_0          12 KB
#     xlwt-1.3.0                 |           py36_0         163 KB
#     libxslt-1.1.33             |       h7d1a2b0_0         577 KB
#     boto3-1.10.19              |             py_0          91 KB
#     olefile-0.46               |             py_0          33 KB
#     numpy-1.17.4               |   py36hc1035e2_0           4 KB
#     et_xmlfile-1.0.1           |           py36_0          20 KB
#     rope-0.14.0                |             py_0         113 KB
#     pathlib2-2.3.5             |           py36_0          37 KB
#     flask-1.1.1                |             py_0          73 KB
#     sphinxcontrib-devhelp-1.0.1|             py_0          23 KB
#     gevent-1.4.0               |   py36h7b6447c_0         2.5 MB
#     python-3.6.9               |       h265db76_0        34.4 MB
#     keyring-19.2.0             |           py36_0          56 KB
#     astropy-3.2.3              |   py36h7b6447c_0         7.2 MB
#     pexpect-4.7.0              |           py36_0          82 KB
#     pytest-remotedata-0.3.2    |           py36_0          15 KB
#     python-libarchive-c-2.8    |          py36_13          23 KB
#     hdf5-1.10.4                |       hb1b8bf9_0         5.3 MB
#     bitarray-1.1.0             |   py36h7b6447c_0          68 KB
#     gmpy2-2.0.8                |   py36h10f8cd9_2         165 KB
#     anaconda-client-1.7.2      |           py36_0         141 KB
#     protobuf-3.10.1            |   py36he6710b0_0         704 KB
#     sphinxcontrib-htmlhelp-1.0.2|             py_0          28 KB
#     prometheus_client-0.7.1    |             py_0          42 KB
#     s3fs-0.4.0                 |             py_0          24 KB
#     backports.functools_lru_cache-1.6.1|             py_0          11 KB
#     statsmodels-0.10.1         |   py36hdd07704_0         9.6 MB
#     pandas-0.25.3              |   py36he6710b0_0        11.5 MB
#     libtiff-4.1.0              |       h2733197_0         589 KB
#     sphinxcontrib-jsmath-1.0.1 |             py_0           8 KB
#     libxml2-2.9.9              |       hea5a465_1         2.0 MB
#     pillow-6.2.1               |   py36h34e0f95_0         640 KB
#     boto-2.49.0                |           py36_0         1.5 MB
#     conda-verify-3.4.2         |             py_1          25 KB
#     zeromq-4.3.1               |       he6710b0_3         666 KB
#     json5-0.8.5                |             py_0          25 KB
#     idna-2.8                   |           py36_0         133 KB
#     mccabe-0.6.1               |           py36_1          14 KB
#     pixman-0.38.0              |       h7b6447c_0         618 KB
#     pickleshare-0.7.5          |           py36_0          13 KB
#     sphinxcontrib-applehelp-1.0.1|             py_0          29 KB
#     pyodbc-4.0.27              |   py36he6710b0_0          70 KB
#     libgfortran-3.0.0          |                1         281 KB
#     bleach-3.1.0               |             py_0         111 KB
#     joblib-0.14.0              |             py_0         201 KB
#     zict-1.0.0                 |             py_0          12 KB
#     patchelf-0.10              |       he6710b0_0          78 KB
#     cryptography-2.8           |   py36h1ba5d50_0         620 KB
#     pytest-doctestplus-0.5.0   |             py_0          21 KB
#     colorama-0.4.1             |             py_0          17 KB
#     jsonschema-3.2.0           |           py36_0          93 KB
#     libarchive-3.3.3           |       h5d8350f_5         1.5 MB
#     py-lief-0.9.0              |   py36h7725739_2         1.5 MB
#     nltk-3.4.5                 |           py36_0         2.1 MB
#     nose-1.3.7                 |           py36_2         214 KB
#     pyqt-5.9.2                 |   py36h05f1152_2         5.6 MB
#     conda-env-2.6.0            |                1           3 KB
#     liblief-0.9.0              |       h7725739_2         4.4 MB
#     pyflakes-2.1.1             |           py36_0         105 KB
#     anaconda-navigator-1.9.7   |           py36_0         4.7 MB
#     dbus-1.13.12               |       h746ee38_0         611 KB
#     conda-build-3.18.11        |           py36_0         541 KB
#     seaborn-0.9.0              |     pyh91ea838_1         164 KB
#     beautifulsoup4-4.8.1       |           py36_0         153 KB
#     mpmath-1.1.0               |           py36_0         970 KB
#     matplotlib-3.1.1           |   py36h5429711_0         6.7 MB
#     heapdict-1.0.1             |             py_0           9 KB
#     pandocfilters-1.4.2        |           py36_1          13 KB
#     pyopenssl-19.1.0           |           py36_0          87 KB
#     pytest-arraydiff-0.3       |   py36h39e3cac_0          15 KB
#     graphite2-1.3.13           |       h23475e2_0         101 KB
#     typed-ast-1.4.0            |   py36h7b6447c_0         208 KB
#     backports.tempfile-1.0     |             py_1          12 KB
#     libprotobuf-3.10.1         |       hd408876_0         4.8 MB
#     ptyprocess-0.6.0           |           py36_0          23 KB
#     pkginfo-1.5.0.1            |           py36_0          43 KB
#     tornado-6.0.3              |   py36h7b6447c_0         643 KB
#     mpfr-4.0.1                 |       hdf1c602_3         575 KB
#     sqlite-3.30.1              |       h7b6447c_0         1.9 MB
#     qtconsole-4.6.0            |             py_0          95 KB
#     pandoc-2.2.3.2             |                0        20.8 MB
#     atomicwrites-1.3.0         |           py36_1          13 KB
#     ipython_genutils-0.2.0     |           py36_0          39 KB
#     qtpy-1.9.0                 |             py_0          39 KB
#     nb_conda_kernels-2.2.2     |           py36_0          37 KB
#     networkx-2.4               |             py_0         1.2 MB
#     pywavelets-1.1.1           |   py36h7b6447c_0         4.4 MB
#     traitlets-4.3.3            |           py36_0         137 KB
#     spyder-kernels-0.5.2       |           py36_0          69 KB
#     terminado-0.8.3            |           py36_0          25 KB
#     decorator-4.4.1            |             py_0          13 KB
#     pytest-5.0.1               |           py36_0         353 KB
#     spyder-3.3.6               |           py36_0         2.5 MB
#     datashape-0.5.4            |           py36_1         100 KB
#     pytest-astropy-0.6.0       |             py_0           8 KB
#     sphinx-2.2.1               |             py_0         1.4 MB
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py36_0           4 KB
#     future-0.18.2              |           py36_0         721 KB
#     qtawesome-0.6.0            |             py_0         671 KB
#     singledispatch-3.4.0.3     |           py36_0          15 KB
#     wcwidth-0.1.7              |           py36_0          25 KB
#     pango-1.42.4               |       h049681c_0         528 KB
#     anaconda-project-0.8.4     |             py_0         215 KB
#     contextlib2-0.6.0.post1    |             py_0          16 KB
#     ipywidgets-7.5.1           |             py_0         107 KB
#     sortedcollections-1.1.2    |           py36_0          18 KB
#     kiwisolver-1.1.0           |   py36he6710b0_0          90 KB
#     jupyterlab-1.2.3           |     pyhf63ae98_0         5.0 MB
#     toolz-0.10.0               |             py_0          50 KB
#     gensim-3.8.0               |   py36h962f231_0        22.9 MB
#     llvmlite-0.30.0            |   py36hd408876_0        17.7 MB
#     requests-2.22.0            |           py36_0          89 KB
#     astroid-2.3.3              |           py36_0         291 KB
#     zipp-0.6.0                 |             py_0           9 KB
#     fastcache-1.1.0            |   py36h7b6447c_0          31 KB
#     tqdm-4.39.0                |             py_0          52 KB
#     libgfortran-ng-7.3.0       |       hdf63c60_0         1.3 MB
#     pycodestyle-2.5.0          |           py36_0          60 KB
#     secretstorage-3.1.1        |           py36_0          24 KB
#     bz2file-0.98               |           py36_1          13 KB
#     nbconvert-5.6.1            |           py36_0         493 KB
#     unixodbc-2.3.7             |       h14c3975_0         319 KB
#     sphinxcontrib-serializinghtml-1.1.3|             py_0          24 KB
#     cython-0.29.14             |   py36he6710b0_0         2.2 MB
#     locket-0.2.0               |           py36_1           8 KB
#     numpy-base-1.17.4          |   py36hde5b4d6_0         5.3 MB
#     attrs-19.3.0               |             py_0          39 KB
#     jupyter_console-6.0.0      |           py36_0          35 KB
#     bokeh-1.4.0                |           py36_0        13.6 MB
#     sqlalchemy-1.3.11          |   py36h7b6447c_0         1.8 MB
#     mkl_fft-1.0.15             |   py36ha843d7b_0         173 KB
#     curl-7.67.0                |       hbc83047_0         145 KB
#     nbformat-4.4.0             |           py36_0         141 KB
#     isort-4.3.21               |           py36_0          68 KB
#     dask-2.8.1                 |             py_0          12 KB
#     mock-3.0.5                 |           py36_0          47 KB
#     tblib-1.5.0                |             py_0          14 KB
#     nb_conda-2.2.1             |           py36_0          33 KB
#     python-dateutil-2.8.0      |           py36_0         281 KB
#     sphinxcontrib-websupport-1.1.2|             py_0          35 KB
#     mistune-0.8.4              |   py36h7b6447c_0          54 KB
#     filelock-3.0.12            |             py_0          12 KB
#     widgetsnbextension-3.5.1   |           py36_0         1.8 MB
#     prompt_toolkit-2.0.10      |             py_0         227 KB
#     ipython-7.9.0              |   py36h39e3cac_0         1.1 MB
#     pcre-8.43                  |       he6710b0_0         260 KB
#     jupyter_client-5.3.4       |           py36_0         136 KB
#     jeepney-0.4.1              |             py_0          21 KB
#     soupsieve-1.9.5            |           py36_0          61 KB
#     greenlet-0.4.15            |   py36h7b6447c_0          20 KB
#     dask-core-2.8.1            |             py_0         584 KB
#     imagesize-1.1.0            |             py_0           8 KB
#     lazy-object-proxy-1.4.3    |   py36h7b6447c_0          31 KB
#     xlrd-1.2.0                 |             py_0         108 KB
#     pycrypto-2.6.1             |   py36h14c3975_9         465 KB
#     conda-4.7.12               |           py36_0         3.0 MB
#     jupyterlab_server-1.0.6    |             py_0          26 KB
#     glib-2.63.1                |       h5a9c865_0         3.4 MB
#     patsy-0.5.1                |           py36_0         380 KB
#     docutils-0.15.2            |           py36_0         742 KB
#     snowballstemmer-2.0.0      |             py_0          58 KB
#     clyent-1.2.2               |           py36_1          18 KB
#     h5py-2.9.0                 |   py36h7918eee_0         1.2 MB
#     jedi-0.15.1                |           py36_0         721 KB
#     jinja2-2.10.3              |             py_0          95 KB
#     jupyter-1.0.0              |           py36_7           6 KB
#     libcurl-7.67.0             |       h20c2e04_0         576 KB
#     itsdangerous-1.1.0         |             py_0          17 KB
#     intel-openmp-2019.4        |              243         876 KB
#     cycler-0.10.0              |           py36_0          13 KB
#     backports.shutil_get_terminal_size-1.0.0|           py36_2           8 KB
#     libssh2-1.8.2              |       h1ba5d50_0         250 KB
#     jupyter_core-4.6.1         |           py36_0          74 KB
#     fsspec-0.6.0               |             py_0          50 KB
#     pyyaml-5.1.2               |   py36h7b6447c_0         189 KB
#     odo-0.5.1                  |           py36_0         193 KB
#     numpydoc-0.9.1             |             py_0          31 KB
#     sortedcontainers-2.1.0     |           py36_0          45 KB
#     backports.weakref-1.0.post1|             py_1           7 KB
#     ------------------------------------------------------------
#                                            Total:       316.2 MB
# The following NEW packages will be INSTALLED:
#
#     atomicwrites:                       1.3.0-py36_1
#     backports.functools_lru_cache:      1.6.1-py_0
#     backports.tempfile:                 1.0-py_1
#     backports.weakref:                  1.0.post1-py_1
#     conda-package-handling:             1.6.0-py36h7b6447c_0
#     fsspec:                             0.6.0-py_0
#     future:                             0.18.2-py36_0
#     importlib_metadata:                 0.23-py36_0
#     jeepney:                            0.4.1-py_0
#     json5:                              0.8.5-py_0
#     jupyterlab_server:                  1.0.6-py_0
#     keyring:                            19.2.0-py36_0
#     libarchive:                         3.3.3-h5d8350f_5
#     liblief:                            0.9.0-h7725739_2
#     lz4-c:                              1.8.1.2-h14c3975_0
#     mock:                               3.0.5-py36_0
#     prometheus_client:                  0.7.1-py_0
#     py-lief:                            0.9.0-py36h7725739_2
#     pyrsistent:                         0.15.6-py36h7b6447c_0
#     pytest-astropy-header:              0.1.1-py_0
#     python-libarchive-c:                2.8-py36_13
#     ripgrep:                            0.10.0-hc07d326_0
#     secretstorage:                      3.1.1-py36_0
#     soupsieve:                          1.9.5-py36_0
#     sphinxcontrib-applehelp:            1.0.1-py_0
#     sphinxcontrib-devhelp:              1.0.1-py_0
#     sphinxcontrib-htmlhelp:             1.0.2-py_0
#     sphinxcontrib-jsmath:               1.0.1-py_0
#     sphinxcontrib-qthelp:               1.0.2-py_0
#     sphinxcontrib-serializinghtml:      1.1.3-py_0
#     spyder-kernels:                     0.5.2-py36_0
#     tqdm:                               4.39.0-py_0
#     typed-ast:                          1.4.0-py36h7b6447c_0
#     wurlitzer:                          2.0.0-py36_0
#     zipp:                               0.6.0-py_0
#     zstd:                               1.3.7-h0b5b093_0
#
# The following packages will be UPDATED:
#
#     _ipyw_jlab_nb_ext_conf:             0.1.0-py36he11e457_0                --> 0.1.0-py36_0
#     alabaster:                          0.7.10-py36h306e16b_0               --> 0.7.12-py_0
#     anaconda-client:                    1.6.14-py36_0                       --> 1.7.2-py36_0
#     anaconda-navigator:                 1.8.7-py36_0                        --> 1.9.7-py36_0
#     anaconda-project:                   0.8.2-py36h44fb852_0                --> 0.8.4-py_0
#     astroid:                            1.6.3-py36_0                        --> 2.3.3-py36_0
#     astropy:                            3.0.2-py36h3010b51_1                --> 3.2.3-py36h7b6447c_0
#     attrs:                              18.1.0-py36_0                       --> 19.3.0-py_0
#     babel:                              2.5.3-py36_0                        --> 2.7.0-py_0
#     backports:                          1.0-py36hfa02d7e_1                  --> 1.0-py_2
#     backports.shutil_get_terminal_size: 1.0.0-py36hfea85ff_2                --> 1.0.0-py36_2
#     beautifulsoup4:                     4.6.0-py36h49b8c8c_1                --> 4.8.1-py36_0
#     bitarray:                           0.8.1-py36h14c3975_1                --> 1.1.0-py36h7b6447c_0
#     bkcharts:                           0.2-py36h735825a_0                  --> 0.2-py36_0
#     blaze:                              0.11.3-py36h4e06776_0               --> 0.11.3-py36_0
#     bleach:                             2.1.3-py36_0                        --> 3.1.0-py_0
#     blosc:                              1.14.3-hdbcaa40_0                   --> 1.16.3-hd408876_0
#     bokeh:                              1.0.4-py36_0                        --> 1.4.0-py36_0
#     boto:                               2.48.0-py36h6e4cd66_1               --> 2.49.0-py36_0
#     boto3:                              1.9.234-py_0                        --> 1.10.19-py_0
#     botocore:                           1.12.234-py_0                       --> 1.13.19-py_0
#     bottleneck:                         1.2.1-py36haac1ea0_0                --> 1.3.1-py36hdd07704_0
#     bz2file:                            0.98-py_0               conda-forge --> 0.98-py36_1
#     bzip2:                              1.0.6-h14c3975_5                    --> 1.0.8-h7b6447c_0
#     cffi:                               1.13.0-py36h2e261b9_0               --> 1.13.2-py36h2e261b9_0
#     click:                              6.7-py36h5253387_0                  --> 7.0-py_0
#     cloudpickle:                        0.5.3-py36_0                        --> 1.2.2-py_0
#     clyent:                             1.2.2-py36h7e57e65_1                --> 1.2.2-py36_1
#     colorama:                           0.3.9-py36h489cec4_0                --> 0.4.1-py_0
#     conda:                              4.5.12-py36_0                       --> 4.7.12-py36_0
#     conda-build:                        3.10.5-py36_0                       --> 3.18.11-py36_0
#     conda-env:                          2.6.0-h36134e3_1                    --> 2.6.0-1
#     conda-verify:                       2.0.0-py36h98955d8_0                --> 3.4.2-py_1
#     contextlib2:                        0.5.5-py36h6c84a62_0                --> 0.6.0.post1-py_0
#     cryptography:                       2.3.1-py36hc365091_0                --> 2.8-py36h1ba5d50_0
#     curl:                               7.60.0-h84994c4_0                   --> 7.67.0-hbc83047_0
#     cycler:                             0.10.0-py36h93f1223_0               --> 0.10.0-py36_0
#     cython:                             0.28.2-py36h14c3975_0               --> 0.29.14-py36he6710b0_0
#     cytoolz:                            0.9.0.1-py36h14c3975_0              --> 0.10.1-py36h7b6447c_0
#     dask:                               0.17.5-py36_0                       --> 2.8.1-py_0
#     dask-core:                          0.17.5-py36_0                       --> 2.8.1-py_0
#     datashape:                          0.5.4-py36h3ad6b5c_0                --> 0.5.4-py36_1
#     dbus:                               1.13.2-h714fa37_1                   --> 1.13.12-h746ee38_0
#     decorator:                          4.3.0-py36_0                        --> 4.4.1-py_0
#     distributed:                        1.21.8-py36_0                       --> 2.8.1-py_0
#     docutils:                           0.14-py36hb0f60f5_0                 --> 0.15.2-py36_0
#     entrypoints:                        0.2.3-py36h1aec115_2                --> 0.3-py36_0
#     et_xmlfile:                         1.0.1-py36hd6bccc3_0                --> 1.0.1-py36_0
#     expat:                              2.2.5-he0dffb1_0                    --> 2.2.6-he6710b0_0
#     fastcache:                          1.0.2-py36h14c3975_2                --> 1.1.0-py36h7b6447c_0
#     filelock:                           3.0.4-py36_0                        --> 3.0.12-py_0
#     flask:                              1.0.2-py36_1                        --> 1.1.1-py_0
#     flask-cors:                         3.0.4-py36_0                        --> 3.0.8-py_0
#     gensim:                             3.7.3-py36he1b5a44_0    conda-forge --> 3.8.0-py36h962f231_0
#     gevent:                             1.3.0-py36h14c3975_0                --> 1.4.0-py36h7b6447c_0
#     glib:                               2.56.1-h000015b_0                   --> 2.63.1-h5a9c865_0
#     glob2:                              0.6-py36he249c77_0                  --> 0.7-py_0
#     gmpy2:                              2.0.8-py36hc8893dd_2                --> 2.0.8-py36h10f8cd9_2
#     graphite2:                          1.3.11-h16798f4_2                   --> 1.3.13-h23475e2_0
#     greenlet:                           0.4.13-py36h14c3975_0               --> 0.4.15-py36h7b6447c_0
#     h5py:                               2.8.0-py36h989c5e5_3                --> 2.9.0-py36h7918eee_0
#     hdf5:                               1.10.2-hba1933b_1                   --> 1.10.4-hb1b8bf9_0
#     heapdict:                           1.0.0-py36_2                        --> 1.0.1-py_0
#     html5lib:                           1.0.1-py36h2f9c1c0_0                --> 1.0.1-py_0
#     idna:                               2.7-py36_1002           conda-forge --> 2.8-py36_0
#     imageio:                            2.3.0-py36_0                        --> 2.6.1-py36_0
#     imagesize:                          1.0.0-py36_0                        --> 1.1.0-py_0
#     intel-openmp:                       2018.0.0-8                          --> 2019.4-243
#     ipykernel:                          4.8.2-py36_0                        --> 5.1.3-py36h39e3cac_0
#     ipython:                            6.4.0-py36_0                        --> 7.9.0-py36h39e3cac_0
#     ipython_genutils:                   0.2.0-py36hb52b0d5_0                --> 0.2.0-py36_0
#     ipywidgets:                         7.2.1-py36_0                        --> 7.5.1-py_0
#     isort:                              4.3.4-py36_0                        --> 4.3.21-py36_0
#     itsdangerous:                       0.24-py36h93cc618_1                 --> 1.1.0-py_0
#     jdcal:                              1.4-py36_0                          --> 1.4.1-py_0
#     jedi:                               0.12.0-py36_1                       --> 0.15.1-py36_0
#     jinja2:                             2.10-py36ha16c418_0                 --> 2.10.3-py_0
#     joblib:                             0.13.2-py36_0                       --> 0.14.0-py_0
#     jsonschema:                         2.6.0-py36_0                        --> 3.2.0-py36_0
#     jupyter:                            1.0.0-py36_4                        --> 1.0.0-py36_7
#     jupyter_client:                     5.2.3-py36_0                        --> 5.3.4-py36_0
#     jupyter_console:                    5.2.0-py36he59e554_1                --> 6.0.0-py36_0
#     jupyter_core:                       4.4.0-py36h7c827e3_0                --> 4.6.1-py36_0
#     jupyterlab:                         0.32.1-py36_0                       --> 1.2.3-pyhf63ae98_0
#     jupyterlab_launcher:                0.10.5-py36_0                       --> 0.13.1-py36_0
#     kiwisolver:                         1.0.1-py36h764f252_0                --> 1.1.0-py36he6710b0_0
#     krb5:                               1.14.2-hcdc1b81_6                   --> 1.16.1-h173b8e3_7
#     lazy-object-proxy:                  1.3.1-py36h10fcdad_0                --> 1.4.3-py36h7b6447c_0
#     libcurl:                            7.60.0-h1ad7b7a_0                   --> 7.67.0-h20c2e04_0
#     libgfortran:                        3.0.0-1                 conda-forge --> 3.0.0-1
#     libgfortran-ng:                     7.2.0-hdf63c60_3                    --> 7.3.0-hdf63c60_0
#     libpng:                             1.6.34-hb9fc6fc_0                   --> 1.6.37-hbc83047_0
#     libprotobuf:                        3.7.1-h8b12597_0        conda-forge --> 3.10.1-hd408876_0
#     libssh2:                            1.8.0-h9cfc8f7_4                    --> 1.8.2-h1ba5d50_0
#     libtiff:                            4.0.9-he85c1e1_1                    --> 4.1.0-h2733197_0
#     libtool:                            2.4.6-h544aabb_3                    --> 2.4.6-h7b6447c_5
#     libxml2:                            2.9.8-h26e45fe_1                    --> 2.9.9-hea5a465_1
#     libxslt:                            1.1.32-h1312cb7_0                   --> 1.1.33-h7d1a2b0_0
#     llvmlite:                           0.23.1-py36hdbcaa40_0               --> 0.30.0-py36hd408876_0
#     locket:                             0.2.0-py36h787c0ad_1                --> 0.2.0-py36_1
#     lxml:                               4.2.1-py36h23eabaa_0                --> 4.4.1-py36hefd8a0e_0
#     markupsafe:                         1.0-py36hd9260cd_1                  --> 1.1.1-py36h7b6447c_0
#     matplotlib:                         3.0.0-py36h5429711_0                --> 3.1.1-py36h5429711_0
#     mccabe:                             0.6.1-py36h5ad9710_1                --> 0.6.1-py36_1
#     mistune:                            0.8.3-py36h14c3975_1                --> 0.8.4-py36h7b6447c_0
#     mkl_fft:                            1.0.14-py36ha843d7b_0               --> 1.0.15-py36ha843d7b_0
#     more-itertools:                     4.1.0-py36_0                        --> 7.2.0-py36_0
#     mpc:                                1.0.3-hec55b23_5                    --> 1.1.0-h10f8cd9_1
#     mpfr:                               3.1.5-h11a74b3_2                    --> 4.0.1-hdf1c602_3
#     mpmath:                             1.0.0-py36hfeacd6b_2                --> 1.1.0-py36_0
#     msgpack-python:                     0.5.6-py36h6bb024c_0                --> 0.6.1-py36hfd86e86_1
#     multipledispatch:                   0.5.0-py36_0                        --> 0.6.0-py36_0
#     nb_conda_kernels:                   2.2.2-py36_0            conda-forge --> 2.2.2-py36_0
#     nbconvert:                          5.4.1-py36_3                        --> 5.6.1-py36_0
#     nbformat:                           4.4.0-py36h31c9010_0                --> 4.4.0-py36_0
#     ncurses:                            6.1-hf484d3e_0                      --> 6.1-he6710b0_1
#     networkx:                           2.1-py36_0                          --> 2.4-py_0
#     nltk:                               3.3.0-py36_0                        --> 3.4.5-py36_0
#     nose:                               1.3.7-py36hcdf7029_2                --> 1.3.7-py36_2
#     notebook:                           5.5.0-py36_0                        --> 6.0.2-py36_0
#     numba:                              0.38.0-py36h637b7d7_0               --> 0.46.0-py36h962f231_0
#     numpy:                              1.16.4-py36h7e9f1db_0               --> 1.17.4-py36hc1035e2_0
#     numpy-base:                         1.16.4-py36hde5b4d6_0               --> 1.17.4-py36hde5b4d6_0
#     numpydoc:                           0.8.0-py36_0                        --> 0.9.1-py_0
#     odo:                                0.5.1-py36h90ed295_0                --> 0.5.1-py36_0
#     olefile:                            0.45.1-py36_0                       --> 0.46-py_0
#     openpyxl:                           2.5.3-py36_0                        --> 3.0.1-py_0
#     openssl:                            1.0.2t-h14c3975_0       conda-forge --> 1.1.1d-h7b6447c_3
#     packaging:                          17.1-py36_0                         --> 19.2-py_0
#     pandas:                             0.24.2-py36he6710b0_0               --> 0.25.3-py36he6710b0_0
#     pandoc:                             1.19.2.1-hea2e7c5_1                 --> 2.2.3.2-0
#     pandocfilters:                      1.4.2-py36ha6701b7_1                --> 1.4.2-py36_1
#     pango:                              1.42.3-h8589676_0                   --> 1.42.4-h049681c_0
#     parso:                              0.2.0-py36_0                        --> 0.5.1-py_0
#     partd:                              0.3.8-py36h36fd896_0                --> 1.1.0-py_0
#     patchelf:                           0.9-hf79760b_2                      --> 0.10-he6710b0_0
#     path.py:                            11.0.1-py36_0                       --> 12.0.2-py_0
#     pathlib2:                           2.3.2-py36_0                        --> 2.3.5-py36_0
#     patsy:                              0.5.0-py36_0                        --> 0.5.1-py36_0
#     pcre:                               8.42-h439df22_0                     --> 8.43-he6710b0_0
#     pexpect:                            4.5.0-py36_0                        --> 4.7.0-py36_0
#     pickleshare:                        0.7.4-py36h63277f8_0                --> 0.7.5-py36_0
#     pillow:                             5.4.1-py36h34e0f95_0                --> 6.2.1-py36h34e0f95_0
#     pixman:                             0.34.0-hceecf20_3                   --> 0.38.0-h7b6447c_0
#     pkginfo:                            1.4.2-py36_1                        --> 1.5.0.1-py36_0
#     pluggy:                             0.6.0-py36hb689045_0                --> 0.13.1-py36_0
#     prompt_toolkit:                     1.0.15-py36h17d85b1_0               --> 2.0.10-py_0
#     protobuf:                           3.7.1-py36he1b5a44_0    conda-forge --> 3.10.1-py36he6710b0_0
#     psutil:                             5.4.5-py36h14c3975_0                --> 5.6.5-py36h7b6447c_0
#     ptyprocess:                         0.5.2-py36h69acd42_0                --> 0.6.0-py36_0
#     py:                                 1.5.3-py36_0                        --> 1.8.0-py_0
#     pycodestyle:                        2.4.0-py36_0                        --> 2.5.0-py36_0
#     pycparser:                          2.19-py36_0                         --> 2.19-py_0
#     pycrypto:                           2.6.1-py36h14c3975_8                --> 2.6.1-py36h14c3975_9
#     pycurl:                             7.43.0.1-py36hb7f436b_0             --> 7.43.0.3-py36h1ba5d50_0
#     pyflakes:                           1.6.0-py36h7bd6a15_0                --> 2.1.1-py36_0
#     pygments:                           2.2.0-py36h0d3125c_0                --> 2.4.2-py_0
#     pylint:                             1.8.4-py36_0                        --> 2.4.4-py36_0
#     pyodbc:                             4.0.23-py36hf484d3e_0               --> 4.0.27-py36he6710b0_0
#     pyopenssl:                          19.0.0-py36_0                       --> 19.1.0-py36_0
#     pyparsing:                          2.2.0-py36hee85983_1                --> 2.4.5-py_0
#     pyqt:                               5.9.2-py36h751905a_0                --> 5.9.2-py36h05f1152_2
#     pytables:                           3.4.3-py36h02b9ad4_2                --> 3.6.1-py36h71ec239_0
#     pytest:                             3.5.1-py36_0                        --> 5.0.1-py36_0
#     pytest-arraydiff:                   0.2-py36_0                          --> 0.3-py36h39e3cac_0
#     pytest-astropy:                     0.3.0-py36_0                        --> 0.6.0-py_0
#     pytest-doctestplus:                 0.1.3-py36_0                        --> 0.5.0-py_0
#     pytest-openfiles:                   0.3.0-py36_0                        --> 0.4.0-py_0
#     pytest-remotedata:                  0.2.1-py36_0                        --> 0.3.2-py36_0
#     python:                             3.6.6-hc3d631a_0                    --> 3.6.9-h265db76_0
#     python-dateutil:                    2.7.3-py36_0                        --> 2.8.0-py36_0
#     pytz:                               2018.4-py36_0                       --> 2019.3-py_0
#     pywavelets:                         0.5.2-py36he602eb0_0                --> 1.1.1-py36h7b6447c_0
#     pyyaml:                             3.12-py36h14c3975_1                 --> 5.1.2-py36h7b6447c_0
#     pyzmq:                              17.0.0-py36h14c3975_0               --> 18.1.0-py36he6710b0_0
#     qt:                                 5.9.6-h8703b6f_2                    --> 5.9.7-h5867ecd_1
#     qtawesome:                          0.4.4-py36h609ed8c_0                --> 0.6.0-py_0
#     qtconsole:                          4.3.1-py36h8f73b5b_0                --> 4.6.0-py_0
#     qtpy:                               1.4.1-py36_0                        --> 1.9.0-py_0
#     requests:                           2.20.0-py36_1000        conda-forge --> 2.22.0-py36_0
#     rope:                               0.10.7-py36h147e2ec_0               --> 0.14.0-py_0
#     s3fs:                               0.1.5-py36_0                        --> 0.4.0-py_0
#     scikit-image:                       0.13.1-py36h14c3975_1               --> 0.15.0-py36he6710b0_0
#     seaborn:                            0.8.1-py36hfad7ec4_0                --> 0.9.0-pyh91ea838_1
#     setuptools:                         41.4.0-py36_0                       --> 42.0.1-py36_0
#     singledispatch:                     3.4.0.3-py36h7a266c3_0              --> 3.4.0.3-py36_0
#     six:                                1.12.0-py36_0                       --> 1.13.0-py36_0
#     smart_open:                         1.9.0-py_0              conda-forge --> 1.9.0-py_0
#     snowballstemmer:                    1.2.1-py36h6febd40_0                --> 2.0.0-py_0
#     sortedcollections:                  0.6.1-py36_0                        --> 1.1.2-py36_0
#     sortedcontainers:                   1.5.10-py36_0                       --> 2.1.0-py36_0
#     sphinx:                             1.7.4-py36_0                        --> 2.2.1-py_0
#     sphinxcontrib:                      1.0-py36h6d0f590_1                  --> 1.0-py36_1
#     sphinxcontrib-websupport:           1.0.1-py36hb5cb234_1                --> 1.1.2-py_0
#     spyder:                             3.2.8-py36_0                        --> 3.3.6-py36_0
#     sqlalchemy:                         1.2.7-py36h6b74fdf_0                --> 1.3.11-py36h7b6447c_0
#     sqlite:                             3.30.0-h7b6447c_0                   --> 3.30.1-h7b6447c_0
#     statsmodels:                        0.9.0-py36h3010b51_0                --> 0.10.1-py36hdd07704_0
#     sympy:                              1.1.1-py36hc6d1c1c_0                --> 1.4-py36_0
#     tblib:                              1.3.2-py36h34cf8b6_0                --> 1.5.0-py_0
#     terminado:                          0.8.1-py36_1                        --> 0.8.3-py36_0
#     testpath:                           0.3.1-py36h8cadb63_0                --> 0.4.4-py_0
#     toolz:                              0.9.0-py36_0                        --> 0.10.0-py_0
#     tornado:                            5.0.2-py36_0                        --> 6.0.3-py36h7b6447c_0
#     traitlets:                          4.3.2-py36h674d592_0                --> 4.3.3-py36_0
#     unicodecsv:                         0.14.1-py36ha668878_0               --> 0.14.1-py36_0
#     unixodbc:                           2.3.6-h1bed415_0                    --> 2.3.7-h14c3975_0
#     urllib3:                            1.23-py36_0                         --> 1.24.2-py36_0
#     wcwidth:                            0.1.7-py36hdf4376a_0                --> 0.1.7-py36_0
#     webencodings:                       0.5.1-py36h800622e_1                --> 0.5.1-py36_1
#     werkzeug:                           0.14.1-py36_0                       --> 0.16.0-py_0
#     widgetsnbextension:                 3.2.1-py36_0                        --> 3.5.1-py36_0
#     wrapt:                              1.10.11-py36h28b7045_0              --> 1.11.2-py36h7b6447c_0
#     xlrd:                               1.1.0-py36h1db9f0c_1                --> 1.2.0-py_0
#     xlsxwriter:                         1.0.4-py36_0                        --> 1.2.6-py_0
#     xlwt:                               1.3.0-py36h7b00a1f_0                --> 1.3.0-py36_0
#     zeromq:                             4.2.5-h439df22_0                    --> 4.3.1-he6710b0_3
#     zict:                               0.1.3-py36h3a3bf81_0                --> 1.0.0-py_0
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates:                    2019.11.28-hecc5488_0   conda-forge --> 2019.10.16-0
#     certifi:                            2019.11.28-py36_0       conda-forge --> 2019.9.11-py36_0
#     nb_conda:                           2.2.1-py36_2            conda-forge --> 2.2.1-py36_0
#     pykerberos:                         1.2.1-py36h14c3975_0                --> 1.1.14-py36h84109d8_2
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
# !pip install tensorflow-gpu==1.14
# Out:
# Collecting tensorflow-gpu==1.14
#   Using cached https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.25.0)
# Processing /home/ubuntu/.cache/pip/wheels/a7/15/a0/0a0561549ad11cdc1bc8fa1191a353efd30facf6bfb507aefc/absl_py-0.8.1-cp36-none-any.whl
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.17.4)
# Requirement already satisfied: wrapt>=1.11.1 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (0.3.2)
# Requirement already satisfied: protobuf>=3.6.1 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (3.10.1)
# Requirement already satisfied: astor>=0.6.0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (0.8.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Using cached https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl
# Collecting google-pasta>=0.1.6
#   Using cached https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl
# Requirement already satisfied: keras-applications>=1.0.6 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.0.8)
# Requirement already satisfied: wheel>=0.26 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (0.33.6)
# Requirement already satisfied: six>=1.10.0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorflow-gpu==1.14) (1.13.0)
# Requirement already satisfied: setuptools in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow-gpu==1.14) (42.0.1.post20191125)
# Collecting markdown>=2.6.8
#   Using cached https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (0.16.0)
# Requirement already satisfied: h5py in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.9.0)
# Installing collected packages: absl-py, markdown, tensorboard, google-pasta, tensorflow-gpu
# Successfully installed absl-py-0.8.1 google-pasta-0.1.8 markdown-3.1.1 tensorboard-1.14.0 tensorflow-gpu-1.14.0

# %%
# !pip install tensorflow-gpu==1.14
# Out:
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████                    | 142.6MB 67.2MB/s eta 0:00:04

# %%
# !pip install keras=='2.1.6'
# Out:
# Collecting keras==2.1.6
#   Using cached https://files.pythonhosted.org/packages/54/e8/eaff7a09349ae9bd40d3ebaf028b49f5e2392c771f294910f75bb608b241/Keras-2.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.9.0 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras==2.1.6) (1.13.0)
# Requirement already satisfied: pyyaml in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras==2.1.6) (5.1.2)
# Requirement already satisfied: scipy>=0.14 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras==2.1.6) (1.3.1)
# Requirement already satisfied: h5py in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras==2.1.6) (2.9.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/ubuntu/anaconda3/lib/python3.6/site-packages (from keras==2.1.6) (1.17.4)
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.0
#     Uninstalling Keras-2.3.0:
#       Successfully uninstalled Keras-2.3.0
# Successfully installed keras-2.1.6

# %%
label_dict={}
def create_label():
    
    with open("/home/ubuntu/composite.txt") as file:
        for _ in range(18227):
            line  = file.readline().strip().split(",")
            label_dict[line[0]] = line[1]
create_label()

#print(label_dict)

# %%
#HERE START GENERATOR THINGY
import os
import random
#nb_words=len(word2vec_model.wv.vocab), will be parameter for tokenizer
tokenizer = Tokenizer(filters='#\n')
tokenizer.fit_on_texts(word2vec_model.wv.vocab.keys())
word_index = tokenizer.word_index
temp_array=[]
batch_size = 75
def get_content(file_names):
    c=0 
    temp_array=[]
    label_array=[]
    while True:
        if c>=len(file_names):
            c=0
        for i,j in enumerate(file_names[c:c+batch_size]):
            l = open("/home/ubuntu/static_mixed/"+j,'r').read().strip()
 
            padded_sequence =  sequence.pad_sequences(tokenizer.texts_to_sequences([l]),maxlen=4000, padding='post',truncating='post')

            temp_array.append(padded_sequence[0])
            if int(label_dict.get(j))==1:
                label_array.append([0,1])
            else:
                label_array.append([1,0])

        temp_array = np.array(temp_array)
        label_array = np.array(label_array)
        #print("\nYIELDING FROM c = ",c," c+batch_size = ",c+batch_size," and length of temp_array = ",len(temp_array),len(label_array))
        yield (temp_array, label_array)
        label_array=[]
        temp_array=[]
        c+=batch_size
files_ = os.listdir("/home/ubuntu/static_mixed")
random.shuffle(files_)
train_data = get_content(files_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
embedding_matrix = np.zeros((len(word2vec_model.wv.vocab)+1,100))
for word, i in word_index.items():
    embedding_matrix[i]=word2vec_model.wv[word]
model = Sequential()
model.add(Embedding(len(word2vec_model.wv.vocab)+1,100,weights=[embedding_matrix],input_length=4000))
model.add(LSTM(128,return_sequences=False))
model.add(Dense(2,activation='softmax'))
model.layers[0].trainable = False
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])
model.summary()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:168: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:175: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 4000, 100)         9848200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 9,965,706
# Trainable params: 117,506
# Non-trainable params: 9,848,200
# _________________________________________________________________

# %%
model=load_model("lstm_model.h5")
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.01),metrics=['accuracy'])

# %%
steps_per_epoch = math.ceil(len(files_)/batch_size)
model.fit_generator(train_data,epochs=1,steps_per_epoch=steps_per_epoch)
# Out:
# Epoch 1/1
# 204/204 [==============================] - 989s 5s/step - loss: 0.1067 - acc: 0.9642

# %%
model.save('lstm_model.h5')

# %%
#VALidation generator

validation_size = 50
def get_validation_data(file_names):
    c=0 
    temp_array=[]
    
    while True:
        if c>=len(file_names):
            c=0
        for i,j in enumerate(file_names[c:c+validation_size]):
            l = open("/home/ubuntu/static_validation/"+j,'r').read().strip()
            padded_sequence =  sequence.pad_sequences(tokenizer.texts_to_sequences([l]),maxlen=4000,padding='post',truncating='post')
            temp_array.append(padded_sequence[0])
            

        temp_array = np.array(temp_array)
        #label_array = np.array(label_array)
        #temp_array = temp_array[..., np.newaxis]
        #print("\nYIELDING FROM c = ",c," c+validation_size = ",c+validation_size," and length of temp_array = ",len(temp_array))
        yield (temp_array)
        
        temp_array=[]
        c+=validation_size
list_of_validation_files = os.listdir("/home/ubuntu/static_validation")
#print(list_of_validation_files)
validation_generator = get_validation_data(list_of_validation_files)

# %%
# print(math.ceil(len(list_of_validation_files)/validation_size))
# raise
prediction = model.predict_generator(validation_generator,math.ceil(len(list_of_validation_files)/validation_size))

# %%
import matplotlib.pyplot as plt
import itertools
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from sklearn.metrics import confusion_matrix
actual_labels=[]
for i,j in enumerate(list_of_validation_files):
    if int(label_dict.get(j))==1:
                actual_labels.append(1)
    else:
                actual_labels.append(0)
#print(actual_labels)
#print(prediction)
prediction1 = np.argmax(prediction, axis=1) 
print(prediction1)

cm = confusion_matrix(actual_labels, prediction1)
plot_confusion_matrix(cm,['benign','malicious'],title='CONFUSION MATRIX')
# Out:
# [0 0 0 ... 0 0 1]
# Confusion matrix, without normalization
# [[1964   36]
#  [  96  904]]

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from funcsigs import signature
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import f1_score
from inspect import signature

def call_precision_recall_curve(truelabel,predictedlabel,actualprediction,label):
    
    #print(truelabel.shape)
    #print(actualprediction.shape)
    
    precision, recall, _ = precision_recall_curve(truelabel,actualprediction)
    au = auc(recall, precision)
    print("Area under graph "+str(au))
    print("-------------------------------------------------")
    rec_score = recall_score(truelabel,predictedlabel,pos_label=1,average='binary')
    precise_score = precision_score(truelabel,predictedlabel,pos_label=1,average='binary')
    f1 = f1_score(truelabel,predictedlabel,pos_label=1, average='binary')
    print("Precision for Malicious apps "+str(precise_score))
    print("Recall for Malicious apps "+str(rec_score))
    print("F1-score for Malicious apps  " + str(f1))
    print("-------------------------------------------------")
    rec_score = recall_score(truelabel,predictedlabel,pos_label=0,average='binary')
    precise_score = precision_score(truelabel,predictedlabel,pos_label=0,average='binary')
    f1 = f1_score(truelabel,predictedlabel,pos_label=0, average='binary')
    print("Precision for Benign apps "+str(precise_score))
    print("Recall for Benign apps "+str(rec_score))
    print("F1-score for Benign apps  " + str(f1))
    
    
    #plot the no-skill line too
    positive_cases = sum(truelabel)/len(truelabel)
    plt.plot([0, 1], [positive_cases, positive_cases], linestyle='--')
    
    
    
    # In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
    step_kwargs = ({'step': 'post'}
                   if 'step' in signature(plt.fill_between).parameters
                   else {})
    plt.step(recall, precision, color='b', alpha=0.2,
             where='post')
    plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall curve')
prediction_for_1=[]
for each_prediction in prediction:
    prediction_for_1.append(each_prediction[1])
call_precision_recall_curve(np.array(actual_labels),np.array(prediction1),np.array(prediction_for_1),1)
# Out:
# Area under graph 0.9659230884598801
# -------------------------------------------------
# Precision for Malicious apps 0.9617021276595744
# Recall for Malicious apps 0.904
# F1-score for Malicious apps  0.9319587628865978
# -------------------------------------------------
# Precision for Benign apps 0.9533980582524272
# Recall for Benign apps 0.982
# F1-score for Benign apps  0.9674876847290641
