# %%
! yes y | %reset
! yes y |conda install -c conda-forge gensim

# %%
#%reset

# %%
import os, sys
import gensim
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
import numpy as np
import pandas as pd
import tensorflow as tf
from datetime import datetime
import re

# %%
now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
root_logdir = "tf_logs2"
logdir = "{}/Staticrun-{}/".format(root_logdir,now)

# %%
def read_data(foldername):
    filenames=[]
    for fname in os.listdir(foldername):
        filenames.append(fname)
        
    return filenames

# %%
existing_files = read_data('/home/ubuntu/Static')
existingfilenames_df = pd.DataFrame(np.array(existing_files).reshape(len(existing_files),1), columns = ['apk'])
existingfilenames_df.head()
# Out:
#                                                  apk
# 0               43cf70608f210b973a5439dcac952a54.txt
# 1  ACB70A1C7F00915FBAFA19B8FFC1E16528158B69614A19...
# 2  AD0D2A7E5728179689F603A57F124CA81C31676CE65DC7...
# 3  AACAA1647BEC55A3DFFD5088F8CCAB2B4261CD24AC9F82...
# 4  AE21B3E03926AD4F2EA4D7688DE2A2556B3589DE9BB603...

# %%
fileswithlabel = pd.read_csv("/home/ubuntu/labelledfileswith-txt.txt")
fileswithlabel.head()
# Out:
#                                                  apk  label
# 0  AD12012BFD86BC73765A73277537B0E1F753379CD7CC9E...      0
# 1  AD120A3582AD38EC1833AB5ABB0ED243ADE70616F798E8...      0
# 2  AD1218C053BCA5096FFF94C28F1DCFAA8B60259FFA3382...      0
# 3  AD121D186298CD48BFBB0A28872DB6CAB4E96BE129856A...      0
# 4  AD122295A328DB33B30BEF8156FCA80DA20701CE566B2B...      0

# %%
fileslistwithlabel = existingfilenames_df.set_index('apk').join(fileswithlabel.set_index('apk'))
del existingfilenames_df

# %%
fileslistwithlabel.head()
# Out:
#                                                     label
# apk
# 43cf70608f210b973a5439dcac952a54.txt                    1
# ACB70A1C7F00915FBAFA19B8FFC1E16528158B69614A19B...      0
# AD0D2A7E5728179689F603A57F124CA81C31676CE65DC7D...      0
# AACAA1647BEC55A3DFFD5088F8CCAB2B4261CD24AC9F827...      0
# AE21B3E03926AD4F2EA4D7688DE2A2556B3589DE9BB603F...      0

# %%
fileslistwithlabel.reset_index(inplace=True)

# %%
#fileslistwithlabel.reset_index(drop=True,inplace=True)

# %%
len(fileslistwithlabel)
# Out:
# 48051

# %%
del fileswithlabel
fileslistwithlabel.head()
# Out:
#                                                  apk  label
# 0               43cf70608f210b973a5439dcac952a54.txt      1
# 1  ACB70A1C7F00915FBAFA19B8FFC1E16528158B69614A19...      0
# 2  AD0D2A7E5728179689F603A57F124CA81C31676CE65DC7...      0
# 3  AACAA1647BEC55A3DFFD5088F8CCAB2B4261CD24AC9F82...      0
# 4  AE21B3E03926AD4F2EA4D7688DE2A2556B3589DE9BB603...      0

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
for train_index,test_index in split.split(fileslistwithlabel,fileslistwithlabel['label']):
    #print(train_index[:10])
    strat_train_set = fileslistwithlabel.loc[train_index]
    strat_test_set = fileslistwithlabel.loc[test_index]

# %%
del fileslistwithlabel
strat_test_set['label'].value_counts() / len(strat_test_set)
# Out:
# 0    0.751014
# 1    0.248986
# Name: label, dtype: float64

# %%
len(strat_test_set)
# Out:
# 9611

# %%
strat_train_set['label'].value_counts() / len(strat_train_set)
# Out:
# 0    0.751041
# 1    0.248959
# Name: label, dtype: float64

# %%
len(strat_train_set)
# Out:
# 38440

# %%
#strat_train_set.set_index('apk')

# %%
strat_train_set.reset_index(drop=True,inplace=True)

# %%
strat_train_set.head()
# Out:
#                                                  apk  label
# 0  AC6513BC89B7D6B058D192570D7411A8D99116F0533E91...      0
# 1  AD488D16BB126B851D4D8ACC32E6A5C3ACE981CEE4B3D4...      0
# 2  AC61E54052E6A21143EB05DA849FA76C358927ECE23AD6...      0
# 3  ABEAA41DAD82EB8E6BC728DAB1B3EDCD05E45CE1F166F4...      0
# 4  AB77B5F70884E9DFDB2454F46CDC32046D761003229EA6...      0

# %%
#!pip3 install --upgrade gensim --user

# %% [markdown]
# #### Also get the pretrained-wordtovec model

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load("/home/ubuntu/wordvectors.kv", mmap='r')
#model = gensim.models.Word2Vec.load('/home/ubuntu/model-all-52dim-skipgram')

# %%
model

# %%
model.wv.vocab
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# {'Ljava/lang/String;.<init>:([BIILjava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0a160>,
#  'Ljava/lang/Object;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0a1d0>,
#  'Ljava/lang/Object;.getClass:()Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0ae10>,
#  'Ljava/lang/Class;.getName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0acf8>,
#  'Ljava/lang/StringBuilder;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0ad30>,
#  'Ljava/lang/String;.substring:(II)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0ab70>,
#  'Ljava/lang/StringBuilder;.append:(Ljava/lang/String;)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0ab38>,
#  'Ljava/lang/Exception;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07d0add8>,
#  'Ljava/lang/Class;.getDeclaredMethod:(Ljava/lang/String;[Ljava/lang/Class;)Ljava/lang/reflect/Method;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93240>,
#  'Ljava/lang/reflect/Method;.setAccessible:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a935c0>,
#  'Landroid/content/Context;.getPackageManager:()Landroid/content/pm/PackageManager;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93908>,
#  'Ljava/lang/RuntimeException;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93940>,
#  'Ljava/util/Set;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93978>,
#  'Ljava/io/File;.<init>:(Ljava/lang/String;Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a939b0>,
#  'Landroid/content/Context;.getClassLoader:()Ljava/lang/ClassLoader;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a939e8>,
#  'Ljava/io/File;.<init>:(Ljava/io/File;Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93a20>,
#  'Ljava/io/InputStream;.available:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93a58>,
#  'Ljava/io/InputStream;.read:([B)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93a90>,
#  'Landroid/app/Application;.onCreate:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93ac8>,
#  'Ljava/lang/StringBuilder;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93b00>,
#  'Ljava/lang/reflect/Field;.get:(Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93b38>,
#  'Ljava/util/ArrayList;.<init>:(Ljava/util/Collection;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93b70>,
#  'Ljava/lang/System;.arraycopy:(Ljava/lang/Object;ILjava/lang/Object;II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93ba8>,
#  'Ljava/util/HashSet;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93be0>,
#  'Ljava/io/OutputStream;.write:([B)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93c18>,
#  'Ljava/io/OutputStream;.flush:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93c50>,
#  'Landroid/app/Application;.attachBaseContext:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93c88>,
#  'Landroid/app/Application;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93cc0>,
#  'Ljava/lang/Class;.getComponentType:()Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93cf8>,
#  'Ljava/lang/StringBuilder;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93d30>,
#  'Ljava/util/List;.listIterator:()Ljava/util/ListIterator;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93d68>,
#  'Ljava/util/ListIterator;.hasNext:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93da0>,
#  'Ljava/util/ListIterator;.next:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93dd8>,
#  'Ljava/util/zip/ZipFile;.<init>:(Ljava/io/File;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93e10>,
#  'Ldalvik/system/DexFile;.loadDex:(Ljava/lang/String;Ljava/lang/String;I)Ldalvik/system/DexFile;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93e48>,
#  'Ljava/util/ArrayList;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93e80>,
#  'Ljava/util/ArrayList;.toArray:([Ljava/lang/Object;)[Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93eb8>,
#  'Ljava/lang/reflect/Field;.set:(Ljava/lang/Object;Ljava/lang/Object;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93ef0>,
#  'Ljava/lang/reflect/Method;.invoke:(Ljava/lang/Object;[Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93f28>,
#  'Landroid/os/Process;.myUid:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93f60>,
#  'Ljava/io/OutputStream;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93f98>,
#  'Ljava/lang/reflect/Field;.setAccessible:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a93fd0>,
#  'Landroid/content/res/AssetManager;.open:(Ljava/lang/String;)Ljava/io/InputStream;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d048>,
#  'Landroid/hardware/Camera;.getNumberOfCameras:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d080>,
#  'Ljava/util/UUID;.randomUUID:()Ljava/util/UUID;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d0b8>,
#  'Ljava/lang/Class;.getSuperclass:()Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d0f0>,
#  'Ljava/io/File;.getAbsolutePath:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d128>,
#  'Ljava/lang/reflect/Constructor;.newInstance:([Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d160>,
#  'Ljava/lang/Class;.getMethod:(Ljava/lang/String;[Ljava/lang/Class;)Ljava/lang/reflect/Method;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d198>,
#  'Ljava/lang/Class;.getConstructor:([Ljava/lang/Class;)Ljava/lang/reflect/Constructor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d1d0>,
#  'Ljava/lang/String;.lastIndexOf:(I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d208>,
#  'Ljava/lang/Class;.forName:(Ljava/lang/String;)Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d240>,
#  'Ljava/lang/reflect/Method;.getReturnType:()Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d278>,
#  'Landroid/content/pm/PackageManager;.getApplicationInfo:(Ljava/lang/String;I)Landroid/content/pm/ApplicationInfo;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d2b0>,
#  'Ljava/lang/reflect/Array;.newInstance:(Ljava/lang/Class;I)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d2e8>,
#  'Ljava/util/ArrayList;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d320>,
#  'Ljava/lang/reflect/Method;.isAccessible:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d358>,
#  'Ljava/util/List;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d390>,
#  'Landroid/content/Context;.getPackageName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d3c8>,
#  'Ljava/io/File;.exists:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d400>,
#  'Ljava/io/InputStream;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d438>,
#  'Ljava/util/List;.isEmpty:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d470>,
#  'Ljava/util/Set;.contains:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d4a8>,
#  'Ljava/lang/Class;.getDeclaredField:(Ljava/lang/String;)Ljava/lang/reflect/Field;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d4e0>,
#  'Ljava/util/ListIterator;.previousIndex:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d518>,
#  'Landroid/content/Context;.getDir:(Ljava/lang/String;I)Ljava/io/File;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d550>,
#  'Ljava/io/File;.mkdirs:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d588>,
#  'Ljava/lang/reflect/Field;.isAccessible:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d5c0>,
#  'Ljava/lang/Class;.getDeclaredMethods:()[Ljava/lang/reflect/Method;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d5f8>,
#  'Ljava/lang/StringBuilder;.append:(C)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d630>,
#  'Ljava/util/Arrays;.asList:([Ljava/lang/Object;)Ljava/util/List;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d668>,
#  'Landroid/content/DialogInterface;.dismiss:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d6a0>,
#  'Landroid/media/AudioManager;.getStreamVolume:(I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d6d8>,
#  'Landroid/media/AudioManager;.getStreamMaxVolume:(I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d710>,
#  'Ljava/util/HashMap;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d748>,
#  'Ljava/lang/StringBuilder;.append:(Ljava/lang/Object;)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d780>,
#  'Landroid/util/Log;.e:(Ljava/lang/String;Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d7b8>,
#  'Ljava/lang/Integer;.valueOf:(I)Ljava/lang/Integer;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d7f0>,
#  'Ljava/util/HashMap;.containsKey:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d828>,
#  'Ljava/util/HashMap;.get:(Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d860>,
#  'Landroid/media/SoundPool;.load:(Landroid/content/Context;II)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d898>,
#  'Ljava/util/HashMap;.put:(Ljava/lang/Object;Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d8d0>,
#  'Ljava/lang/System;.currentTimeMillis:()J': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d908>,
#  'Ljava/lang/StringBuilder;.append:(J)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d940>,
#  'Landroid/util/Log;.v:(Ljava/lang/String;Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d978>,
#  'Landroid/media/SoundPool;.stop:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d9b0>,
#  'Landroid/media/SoundPool;.play:(IFFIIF)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2d9e8>,
#  'Ljava/lang/Integer;.intValue:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2da20>,
#  'Ljava/lang/Thread;.getState:()Ljava/lang/Thread$State;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2da58>,
#  'Ljava/util/HashMap;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2da90>,
#  'Ljava/util/HashMap;.entrySet:()Ljava/util/Set;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dac8>,
#  'Ljava/util/Set;.iterator:()Ljava/util/Iterator;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2db00>,
#  'Ljava/util/Iterator;.hasNext:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2db38>,
#  'Ljava/util/Iterator;.next:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2db70>,
#  'Ljava/util/Map$Entry;.getValue:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dba8>,
#  'Landroid/content/Context;.getString:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dbe0>,
#  'Landroid/media/SoundPool;.release:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dc18>,
#  'Landroid/content/Context;.getSystemService:(Ljava/lang/String;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dc50>,
#  'Landroid/media/AudioAttributes$Builder;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dc88>,
#  'Landroid/media/AudioAttributes$Builder;.setUsage:(I)Landroid/media/AudioAttributes$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dcc0>,
#  'Landroid/media/AudioAttributes$Builder;.setContentType:(I)Landroid/media/AudioAttributes$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dcf8>,
#  'Landroid/media/AudioAttributes$Builder;.build:()Landroid/media/AudioAttributes;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dd30>,
#  'Landroid/media/SoundPool$Builder;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dd68>,
#  'Landroid/media/SoundPool$Builder;.setAudioAttributes:(Landroid/media/AudioAttributes;)Landroid/media/SoundPool$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dda0>,
#  'Landroid/media/SoundPool$Builder;.setMaxStreams:(I)Landroid/media/SoundPool$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2ddd8>,
#  'Landroid/media/SoundPool$Builder;.build:()Landroid/media/SoundPool;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2de10>,
#  'Landroid/media/SoundPool;.<init>:(III)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2de48>,
#  'Ljava/util/Map$Entry;.getKey:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2de80>,
#  'Landroid/preference/PreferenceManager;.getDefaultSharedPreferences:(Landroid/content/Context;)Landroid/content/SharedPreferences;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2deb8>,
#  'Landroid/content/SharedPreferences;.getString:(Ljava/lang/String;Ljava/lang/String;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2def0>,
#  'Ljava/lang/Integer;.parseInt:(Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2df28>,
#  'Ljava/lang/Float;.parseFloat:(Ljava/lang/String;)F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2df60>,
#  'Ljava/lang/String;.split:(Ljava/lang/String;)[Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2df98>,
#  'Ljava/lang/Thread;.isAlive:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a2dfd0>,
#  'Ljava/lang/Thread;.sleep:(J)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37048>,
#  'Ljava/lang/Thread;.start:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37080>,
#  'Ljava/lang/InterruptedException;.printStackTrace:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a370b8>,
#  'Ljava/lang/String;.equals:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a370f0>,
#  'Landroid/media/SoundPool;.autoPause:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37128>,
#  'Landroid/view/View;.getTag:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37160>,
#  'Ljava/lang/Object;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37198>,
#  'Ljava/lang/Integer;.valueOf:(Ljava/lang/String;)Ljava/lang/Integer;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a371d0>,
#  'Landroid/widget/Toast;.makeText:(Landroid/content/Context;Ljava/lang/CharSequence;I)Landroid/widget/Toast;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37208>,
#  'Landroid/widget/Toast;.show:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37240>,
#  'Landroid/view/View;.setPressed:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37278>,
#  'Ljava/lang/StringBuilder;.append:(I)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a372b0>,
#  'Ljava/util/List;.get:(I)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a372e8>,
#  'Landroid/content/SharedPreferences;.edit:()Landroid/content/SharedPreferences$Editor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37320>,
#  'Landroid/content/SharedPreferences$Editor;.putString:(Ljava/lang/String;Ljava/lang/String;)Landroid/content/SharedPreferences$Editor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37358>,
#  'Landroid/content/SharedPreferences$Editor;.apply:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37390>,
#  'Ljava/lang/StringBuffer;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a373c8>,
#  'Landroid/app/Activity;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37400>,
#  'Landroid/app/Activity;.onCreate:(Landroid/os/Bundle;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37438>,
#  'Landroid/view/Window;.setFlags:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37470>,
#  'Ljava/lang/Thread;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a374a8>,
#  'Lcom/google/android/gms/ads/AdListener;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a374e0>,
#  'Landroid/content/SharedPreferences;.getBoolean:(Ljava/lang/String;Z)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37518>,
#  'Ljava/util/List;.contains:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37550>,
#  'Ljava/util/List;.indexOf:(Ljava/lang/Object;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37588>,
#  'Landroid/widget/SeekBar;.getMax:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a375c0>,
#  'Landroid/widget/RelativeLayout;.getWidth:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a375f8>,
#  'Landroid/widget/RelativeLayout;.getMeasuredWidth:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37630>,
#  'Landroid/content/res/Resources;.getDisplayMetrics:()Landroid/util/DisplayMetrics;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37668>,
#  'Landroid/widget/RelativeLayout;.scrollTo:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a376a0>,
#  'Ljava/lang/String;.contains:(Ljava/lang/CharSequence;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a376d8>,
#  'Landroid/widget/SeekBar;.setProgress:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37710>,
#  'Landroid/app/AlertDialog$Builder;.<init>:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37748>,
#  'Landroid/app/AlertDialog$Builder;.setTitle:(Ljava/lang/CharSequence;)Landroid/app/AlertDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37780>,
#  'Landroid/app/AlertDialog$Builder;.setSingleChoiceItems:([Ljava/lang/CharSequence;ILandroid/content/DialogInterface$OnClickListener;)Landroid/app/AlertDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a377b8>,
#  'Landroid/app/AlertDialog$Builder;.create:()Landroid/app/AlertDialog;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a377f0>,
#  'Landroid/app/AlertDialog;.getListView:()Landroid/widget/ListView;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37828>,
#  'Landroid/widget/ListView;.setFastScrollEnabled:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37860>,
#  'Landroid/app/AlertDialog;.show:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37898>,
#  'Ljava/util/List;.iterator:()Ljava/util/Iterator;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a378d0>,
#  'Landroid/widget/ImageButton;.setImageBitmap:(Landroid/graphics/Bitmap;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37908>,
#  'Landroid/view/MotionEvent;.getActionIndex:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37940>,
#  'Landroid/view/MotionEvent;.getPointerId:(I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37978>,
#  'Landroid/view/MotionEvent;.getActionMasked:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a379b0>,
#  'Landroid/view/MotionEvent;.getPressure:()F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a379e8>,
#  'Ljava/lang/String;.length:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37a20>,
#  'Landroid/view/MotionEvent;.getRawX:()F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37a58>,
#  'Landroid/view/MotionEvent;.getX:(I)F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37a90>,
#  'Landroid/view/MotionEvent;.getY:(I)F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37ac8>,
#  'Landroid/view/MotionEvent;.getX:()F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37b00>,
#  'Landroid/view/MotionEvent;.getY:()F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37b38>,
#  'Landroid/widget/RelativeLayout;.getScrollX:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37b70>,
#  'Landroid/view/MotionEvent;.getAction:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37ba8>,
#  'Landroid/view/MotionEvent;.getPointerCount:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37be0>,
#  'Landroid/view/MotionEvent;.getRawY:()F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37c18>,
#  'Lcom/google/android/gms/ads/AdView;.destroy:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37c50>,
#  'Lcom/facebook/ads/AdView;.destroy:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37c88>,
#  'Landroid/net/ConnectivityManager;.getActiveNetworkInfo:()Landroid/net/NetworkInfo;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37cc0>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.dispatch:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37cf8>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.stopSession:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37d30>,
#  'Landroid/app/Activity;.onDestroy:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37d68>,
#  'Ljava/util/ArrayList;.iterator:()Ljava/util/Iterator;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37da0>,
#  'Landroid/widget/RelativeLayout;.removeViewInLayout:(Landroid/view/View;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37dd8>,
#  'Landroid/util/TypedValue;.applyDimension:(IFLandroid/util/DisplayMetrics;)F': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37e10>,
#  'Landroid/widget/LinearLayout$LayoutParams;.<init>:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37e48>,
#  'Landroid/widget/RelativeLayout;.setLayoutParams:(Landroid/view/ViewGroup$LayoutParams;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37e80>,
#  'Landroid/widget/RelativeLayout$LayoutParams;.<init>:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37eb8>,
#  'Landroid/widget/ImageButton;.setLayoutParams:(Landroid/view/ViewGroup$LayoutParams;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37ef0>,
#  'Landroid/widget/RelativeLayout$LayoutParams;.addRule:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37f28>,
#  'Landroid/widget/RelativeLayout$LayoutParams;.setMargins:(IIII)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37f60>,
#  'Ljava/lang/Float;.valueOf:(F)Ljava/lang/Float;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37f98>,
#  'Ljava/lang/Float;.intValue:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a37fd0>,
#  'Landroid/view/View;.setOnTouchListener:(Landroid/view/View$OnTouchListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44048>,
#  'Landroid/view/View;.setOnClickListener:(Landroid/view/View$OnClickListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44080>,
#  'Landroid/widget/SeekBar;.setOnSeekBarChangeListener:(Landroid/widget/SeekBar$OnSeekBarChangeListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a440b8>,
#  'Landroid/widget/RelativeLayout;.measure:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a440f0>,
#  'Landroid/support/v4/content/ContextCompat;.getDrawable:(Landroid/content/Context;I)Landroid/graphics/drawable/Drawable;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44128>,
#  'Landroid/widget/SeekBar;.setProgressDrawable:(Landroid/graphics/drawable/Drawable;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44160>,
#  'Landroid/graphics/drawable/Drawable;.setAlpha:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44198>,
#  'Landroid/widget/SeekBar;.setThumb:(Landroid/graphics/drawable/Drawable;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a441d0>,
#  'Landroid/graphics/BitmapFactory;.decodeResource:(Landroid/content/res/Resources;I)Landroid/graphics/Bitmap;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44208>,
#  'Lcom/google/android/gms/ads/AdView;.<init>:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44240>,
#  'Lcom/google/android/gms/ads/AdView;.setAdUnitId:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44278>,
#  'Lcom/google/android/gms/ads/AdView;.setAdSize:(Lcom/google/android/gms/ads/AdSize;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a442b0>,
#  'Lcom/facebook/ads/AdView;.<init>:(Landroid/content/Context;Ljava/lang/String;Lcom/facebook/ads/AdSize;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a442e8>,
#  'Landroid/widget/TextView;.setTextSize:(IF)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44320>,
#  'Landroid/widget/TextView;.getPaddingRight:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44358>,
#  'Landroid/widget/TextView;.getPaddingBottom:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44390>,
#  'Landroid/widget/TextView;.setPadding:(IIII)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a443c8>,
#  'Landroid/widget/RelativeLayout$LayoutParams;.addRule:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44400>,
#  'Landroid/widget/RelativeLayout;.addView:(Landroid/view/View;Landroid/view/ViewGroup$LayoutParams;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44438>,
#  'Landroid/widget/RelativeLayout;.getLayoutParams:()Landroid/view/ViewGroup$LayoutParams;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44470>,
#  'Ljava/util/Collection;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a444a8>,
#  'Lcom/facebook/ads/AdSettings;.addTestDevices:(Ljava/util/Collection;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a444e0>,
#  'Lcom/facebook/ads/AdView;.loadAd:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44518>,
#  'Lcom/facebook/ads/AdView;.setAdListener:(Lcom/facebook/ads/AdListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44550>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.getInstance:()Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44588>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.startNewSession:(Ljava/lang/String;Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a445c0>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.setDebug:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a445f8>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.trackPageView:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44630>,
#  'Landroid/view/Window;.addFlags:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44668>,
#  'Landroid/app/Activity;.onResume:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a446a0>,
#  'Landroid/widget/ImageView;.setImageDrawable:(Landroid/graphics/drawable/Drawable;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a446d8>,
#  'Landroid/content/Intent;.<init>:(Landroid/content/Context;Ljava/lang/Class;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44710>,
#  'Landroid/content/Intent;.addFlags:(I)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44748>,
#  'Landroid/view/Menu;.clear:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44780>,
#  'Landroid/view/MenuInflater;.inflate:(ILandroid/view/Menu;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a447b8>,
#  'Landroid/app/Activity;.onPrepareOptionsMenu:(Landroid/view/Menu;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a447f0>,
#  'Landroid/app/Activity;.onStop:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44828>,
#  'Landroid/view/MenuItem;.getItemId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44860>,
#  'Ljava/util/Set;.clear:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44898>,
#  'Landroid/app/Activity;.onPause:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a448d0>,
#  'Ljava/lang/StringBuffer;.append:(Ljava/lang/String;)Ljava/lang/StringBuffer;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44908>,
#  'Landroid/view/LayoutInflater;.from:(Landroid/content/Context;)Landroid/view/LayoutInflater;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44940>,
#  'Landroid/view/LayoutInflater;.inflate:(ILandroid/view/ViewGroup;)Landroid/view/View;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44978>,
#  'Landroid/view/View;.findViewById:(I)Landroid/view/View;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a449b0>,
#  'Landroid/widget/LinearLayout;.setBackgroundColor:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a449e8>,
#  'Landroid/widget/TextView;.setText:(Ljava/lang/CharSequence;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44a20>,
#  'Ljava/lang/StringBuffer;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44a58>,
#  'Landroid/app/AlertDialog$Builder;.setView:(Landroid/view/View;)Landroid/app/AlertDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44a90>,
#  'Landroid/app/AlertDialog;.setButton:(ILjava/lang/CharSequence;Landroid/content/DialogInterface$OnClickListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44ac8>,
#  'Landroid/widget/TextView;.<init>:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44b00>,
#  'Landroid/widget/TextView;.setTextSize:(F)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44b38>,
#  'Landroid/widget/TextView;.setTypeface:(Landroid/graphics/Typeface;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44b70>,
#  'Landroid/widget/TextView;.setTextColor:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44ba8>,
#  'Landroid/widget/ImageButton;.getId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44be0>,
#  'Landroid/widget/TextView;.setLayoutParams:(Landroid/view/ViewGroup$LayoutParams;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44c18>,
#  'Landroid/widget/RelativeLayout;.addView:(Landroid/view/View;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44c50>,
#  'Ljava/util/ArrayList;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44c88>,
#  'Ljava/lang/StringBuffer;.length:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44cc0>,
#  'Ljava/lang/StringBuffer;.delete:(II)Ljava/lang/StringBuffer;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44cf8>,
#  'Ljava/util/List;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44d30>,
#  'Lcom/google/android/apps/analytics/GoogleAnalyticsTracker;.trackEvent:(Ljava/lang/String;Ljava/lang/String;Ljava/lang/String;I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44d68>,
#  'Ljava/util/Collections;.reverse:(Ljava/util/List;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44da0>,
#  'Ljava/lang/String;.valueOf:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44dd8>,
#  'Ljava/util/List;.addAll:(Ljava/util/Collection;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44e10>,
#  'Ljava/lang/Float;.longValue:()J': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44e48>,
#  'Landroid/view/View;.getId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44e80>,
#  'Landroid/content/SharedPreferences$Editor;.putBoolean:(Ljava/lang/String;Z)Landroid/content/SharedPreferences$Editor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44eb8>,
#  'Landroid/content/SharedPreferences$Editor;.putInt:(Ljava/lang/String;I)Landroid/content/SharedPreferences$Editor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44ef0>,
#  'Landroid/media/MediaPlayer;.isPlaying:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44f28>,
#  'Landroid/media/MediaPlayer;.stop:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44f60>,
#  'Ljava/lang/Float;.<init>:(F)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44f98>,
#  'Ljava/lang/String;.replaceAll:(Ljava/lang/String;Ljava/lang/String;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a44fd0>,
#  'Landroid/view/View;.setOnLongClickListener:(Landroid/view/View$OnLongClickListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e048>,
#  'Ljava/lang/StringBuilder;.append:(Z)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e080>,
#  'Landroid/widget/Button;.setOnClickListener:(Landroid/view/View$OnClickListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e0b8>,
#  'Ljava/util/GregorianCalendar;.<init>:(III)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e0f0>,
#  'Ljava/util/GregorianCalendar;.getTimeInMillis:()J': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e128>,
#  'Landroid/os/Handler;.postDelayed:(Ljava/lang/Runnable;J)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e160>,
#  'Ljava/util/List;.clear:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e198>,
#  'Ljava/util/Collections;.sort:(Ljava/util/List;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e1d0>,
#  'Ljava/util/List;.toArray:([Ljava/lang/Object;)[Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e208>,
#  'Landroid/app/AlertDialog;.getWindow:()Landroid/view/Window;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e240>,
#  'Landroid/view/Window;.setLayout:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e278>,
#  'Landroid/app/AlertDialog$Builder;.setPositiveButton:(Ljava/lang/CharSequence;Landroid/content/DialogInterface$OnClickListener;)Landroid/app/AlertDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e2b0>,
#  'Landroid/app/AlertDialog$Builder;.setNegativeButton:(Ljava/lang/CharSequence;Landroid/content/DialogInterface$OnClickListener;)Landroid/app/AlertDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e2e8>,
#  'Landroid/widget/Button;.setText:(Ljava/lang/CharSequence;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e320>,
#  'Ljava/io/File;.listFiles:()[Ljava/io/File;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e358>,
#  'Ljava/io/File;.getName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e390>,
#  'Ljava/lang/String;.endsWith:(Ljava/lang/String;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e3c8>,
#  'Ljava/io/File;.isFile:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e400>,
#  'Ljava/io/File;.isDirectory:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e438>,
#  'Ljava/lang/Integer;.toString:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e470>,
#  'Landroid/util/Log;.i:(Ljava/lang/String;Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e4a8>,
#  'Landroid/view/View;.setBackgroundResource:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e4e0>,
#  'Ljava/lang/String;.replace:(Ljava/lang/CharSequence;Ljava/lang/CharSequence;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e518>,
#  'Landroid/os/Handler;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e550>,
#  'Landroid/media/MediaPlayer;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e588>,
#  'Ljava/lang/CharSequence;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e5c0>,
#  'Ljava/lang/StringBuffer;.<init>:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e5f8>,
#  'Landroid/media/MediaPlayer;.setDataSource:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e630>,
#  'Landroid/media/MediaPlayer;.setVolume:(FF)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e668>,
#  'Landroid/media/MediaPlayer;.prepare:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e6a0>,
#  'Landroid/media/MediaPlayer;.start:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e6d8>,
#  'Landroid/media/MediaPlayer;.setOnCompletionListener:(Landroid/media/MediaPlayer$OnCompletionListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e710>,
#  'Ljava/lang/Exception;.getMessage:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e748>,
#  'Ljava/lang/Class;.getSimpleName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e780>,
#  'Landroid/widget/Button;.getText:()Ljava/lang/CharSequence;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e7b8>,
#  'Ljava/io/File;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e7f0>,
#  'Ljava/io/File;.list:()[Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e828>,
#  'Ljava/io/FileInputStream;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e860>,
#  'Ljava/io/InputStreamReader;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e898>,
#  'Ljava/io/BufferedReader;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e8d0>,
#  'Landroid/util/Log;.d:(Ljava/lang/String;Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e908>,
#  'Ljava/io/FileInputStream;.<init>:(Ljava/io/File;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e940>,
#  'Ljava/io/InputStreamReader;.<init>:(Ljava/io/InputStream;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e978>,
#  'Ljava/io/BufferedReader;.<init>:(Ljava/io/Reader;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e9b0>,
#  'Ljava/io/BufferedReader;.readLine:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4e9e8>,
#  'Ljava/lang/String;.indexOf:(Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ea20>,
#  'Ljava/lang/String;.indexOf:(Ljava/lang/String;I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ea58>,
#  'Landroid/content/ContentResolver;.query:(Landroid/net/Uri;[Ljava/lang/String;Ljava/lang/String;[Ljava/lang/String;Ljava/lang/String;)Landroid/database/Cursor;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ea90>,
#  'Landroid/database/Cursor;.moveToFirst:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eac8>,
#  'Landroid/database/Cursor;.isAfterLast:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eb00>,
#  'Landroid/database/Cursor;.getString:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eb38>,
#  'Landroid/database/Cursor;.moveToNext:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eb70>,
#  'Landroid/database/Cursor;.close:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eba8>,
#  'Landroid/app/AlertDialog;.dismiss:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ebe0>,
#  'Ljava/util/TreeSet;.clear:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ec18>,
#  'Lcom/facebook/ads/AdError;.getErrorCode:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ec50>,
#  'Lcom/facebook/ads/AdError;.getErrorMessage:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ec88>,
#  'Lcom/google/android/gms/ads/AdRequest$Builder;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ecc0>,
#  'Lcom/google/android/gms/ads/AdRequest$Builder;.addTestDevice:(Ljava/lang/String;)Lcom/google/android/gms/ads/AdRequest$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ecf8>,
#  'Lcom/google/android/gms/ads/AdRequest$Builder;.build:()Lcom/google/android/gms/ads/AdRequest;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ed30>,
#  'Lcom/google/android/gms/ads/AdView;.loadAd:(Lcom/google/android/gms/ads/AdRequest;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ed68>,
#  'Lcom/google/android/gms/ads/AdView;.setAdListener:(Lcom/google/android/gms/ads/AdListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eda0>,
#  'Landroid/app/ListActivity;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4edd8>,
#  'Landroid/app/ListActivity;.onListItemClick:(Landroid/widget/ListView;Landroid/view/View;IJ)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ee10>,
#  'Landroid/app/ListActivity;.onCreate:(Landroid/os/Bundle;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ee48>,
#  'Landroid/app/ListActivity;.onResume:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ee80>,
#  'Landroid/os/Environment;.getExternalStorageState:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eeb8>,
#  'Landroid/os/Environment;.getExternalStorageDirectory:()Ljava/io/File;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4eef0>,
#  'Ljava/io/File;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ef28>,
#  'Ljava/io/FileOutputStream;.<init>:(Ljava/io/File;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ef60>,
#  'Ljava/lang/String;.getBytes:()[B': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4ef98>,
#  'Landroid/net/Uri;.fromFile:(Ljava/io/File;)Landroid/net/Uri;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a4efd0>,
#  'Landroid/content/Intent;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58048>,
#  'Landroid/content/Intent;.putExtra:(Ljava/lang/String;Ljava/lang/String;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58080>,
#  'Landroid/content/Intent;.putExtra:(Ljava/lang/String;[Ljava/lang/String;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a580b8>,
#  'Landroid/content/Intent;.putExtra:(Ljava/lang/String;Landroid/os/Parcelable;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a580f0>,
#  'Landroid/content/Intent;.setType:(Ljava/lang/String;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58128>,
#  'Landroid/content/Intent;.createChooser:(Landroid/content/Intent;Ljava/lang/CharSequence;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58160>,
#  'Landroid/content/SharedPreferences$Editor;.commit:()Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58198>,
#  'Ljava/util/Vector;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a581d0>,
#  'Ljava/io/FileInputStream;.read:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58208>,
#  'Ljava/util/Vector;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58240>,
#  'Ljava/util/Vector;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58278>,
#  'Ljava/util/Vector;.get:(I)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a582b0>,
#  'Ljava/util/Vector;.clear:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a582e8>,
#  'Landroid/os/HandlerThread;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58320>,
#  'Landroid/os/HandlerThread;.start:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58358>,
#  'Landroid/widget/SeekBar;.getId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58390>,
#  'Ljava/lang/StringBuilder;.append:(F)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a583c8>,
#  'Landroid/widget/SeekBar;.getProgress:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58400>,
#  'Landroid/widget/CheckBox;.setChecked:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58438>,
#  'Landroid/net/Uri;.parse:(Ljava/lang/String;)Landroid/net/Uri;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58470>,
#  'Landroid/content/Intent;.setData:(Landroid/net/Uri;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a584a8>,
#  'Landroid/widget/CheckBox;.setOnCheckedChangeListener:(Landroid/widget/CompoundButton$OnCheckedChangeListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a584e0>,
#  'Landroid/content/SharedPreferences;.contains:(Ljava/lang/String;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58518>,
#  'Landroid/widget/CompoundButton;.getId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58550>,
#  'Lorg/xmlpull/v1/XmlPullParserFactory;.newInstance:()Lorg/xmlpull/v1/XmlPullParserFactory;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58588>,
#  'Lorg/xmlpull/v1/XmlPullParserFactory;.setNamespaceAware:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a585c0>,
#  'Lorg/xmlpull/v1/XmlPullParserFactory;.newPullParser:()Lorg/xmlpull/v1/XmlPullParser;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a585f8>,
#  'Ljava/io/StringReader;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58630>,
#  'Lorg/xmlpull/v1/XmlPullParser;.setInput:(Ljava/io/Reader;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58668>,
#  'Lorg/xmlpull/v1/XmlPullParser;.next:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a586a0>,
#  'Lorg/xmlpull/v1/XmlPullParser;.getEventType:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a586d8>,
#  'Lorg/xmlpull/v1/XmlPullParser;.getName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58710>,
#  'Lorg/xmlpull/v1/XmlPullParser;.getAttributeValue:(Ljava/lang/String;Ljava/lang/String;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58748>,
#  'Landroid/util/Log;.v:(Ljava/lang/String;Ljava/lang/String;Ljava/lang/Throwable;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58780>,
#  'Landroid/app/Activity;.onStart:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a587b8>,
#  'Landroid/app/Activity;.onBackPressed:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a587f0>,
#  'Landroid/widget/Button;.setOnLongClickListener:(Landroid/view/View$OnLongClickListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58828>,
#  'Landroid/os/Handler;.post:(Ljava/lang/Runnable;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58860>,
#  'Landroid/os/Handler;.removeCallbacks:(Ljava/lang/Runnable;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58898>,
#  'Ljava/util/Vector;.remove:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a588d0>,
#  'Ljava/io/ByteArrayOutputStream;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58908>,
#  'Ljava/io/PrintStream;.<init>:(Ljava/io/OutputStream;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58940>,
#  'Ljava/lang/Throwable;.getMessage:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58978>,
#  'Ljava/lang/Throwable;.printStackTrace:(Ljava/io/PrintStream;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a589b0>,
#  'Ljava/io/PrintStream;.flush:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a589e8>,
#  'Ljava/io/ByteArrayOutputStream;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58a20>,
#  '[Lcom/immersion/uhl/TouchSenseVersion;.clone:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58a58>,
#  'Ljava/lang/Enum;.valueOf:(Ljava/lang/Class;Ljava/lang/String;)Ljava/lang/Enum;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58a90>,
#  'Ljava/lang/Enum;.<init>:(Ljava/lang/String;I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58ac8>,
#  'Lcom/google/android/gms/ads/InterstitialAd;.<init>:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58b00>,
#  'Lcom/google/android/gms/ads/InterstitialAd;.setAdUnitId:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58b38>,
#  'Lcom/google/android/gms/ads/InterstitialAd;.setAdListener:(Lcom/google/android/gms/ads/AdListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58b70>,
#  'Lcom/facebook/ads/InterstitialAd;.destroy:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58ba8>,
#  'Landroid/content/res/Resources;.getXml:(I)Landroid/content/res/XmlResourceParser;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58be0>,
#  'Landroid/content/res/XmlResourceParser;.next:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58c18>,
#  'Landroid/content/res/XmlResourceParser;.getEventType:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58c50>,
#  'Landroid/content/res/XmlResourceParser;.getName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58c88>,
#  'Landroid/content/res/XmlResourceParser;.getAttributeValue:(Ljava/lang/String;Ljava/lang/String;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58cc0>,
#  'Ljava/util/Map;.put:(Ljava/lang/Object;Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58cf8>,
#  'Ljava/util/Map;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58d30>,
#  'Ljava/util/Map;.get:(Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58d68>,
#  'Ljava/util/Set;.equals:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58da0>,
#  'Ljava/lang/String;.matches:(Ljava/lang/String;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58dd8>,
#  'Ljava/lang/String;.charAt:(I)C': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58e10>,
#  'Ljava/lang/String;.toUpperCase:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58e48>,
#  'Ljava/util/List;.removeAll:(Ljava/util/Collection;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58e80>,
#  'Ljava/util/TreeSet;.first:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58eb8>,
#  'Ljava/util/TreeSet;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58ef0>,
#  'Ljava/util/TreeSet;.iterator:()Ljava/util/Iterator;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58f28>,
#  'Ljava/util/TreeSet;.add:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58f60>,
#  'Ljava/util/TreeSet;.containsAll:(Ljava/util/Collection;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58f98>,
#  'Ljava/util/Set;.size:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a58fd0>,
#  'Ljava/util/Random;.nextInt:(I)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a62048>,
#  'Ljava/lang/Math;.round:(F)I': <gensim.models.keyedvectors.Vocab at 0x7f3f07a62080>,
#  'Landroid/app/AlertDialog;.setOnKeyListener:(Landroid/content/DialogInterface$OnKeyListener;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a620b8>,
#  'Ljava/util/Date;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a620f0>,
#  'Ljava/util/Date;.getTime:()J': <gensim.models.keyedvectors.Vocab at 0x7f3f07a62128>,
#  'Ljava/util/Random;.<init>:(J)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a62160>,
#  'Landroid/content/Intent;.getExtras:()Landroid/os/Bundle;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a62198>,
# ...
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setDescription:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24b70>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setPicture:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24ba8>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setLink:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24be0>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setApplicationName:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24c18>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setPlace:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24c50>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setRef:(Ljava/lang/String;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24c88>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setFriends:(Ljava/util/List;)Lcom/facebook/widget/FacebookDialog$ShareDialogBuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24cc0>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.setRequestCode:(I)Lcom/facebook/widget/FacebookDialog$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24cf8>,
#  'Lcom/facebook/widget/FacebookDialog$ShareDialogBuilder;.build:()Lcom/facebook/widget/FacebookDialog;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24d30>,
#  'Lcom/facebook/widget/FacebookDialog;.canPresentOpenGraphActionDialog:(Landroid/content/Context;[Lcom/facebook/widget/FacebookDialog$OpenGraphActionDialogFeature;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24d68>,
#  'Lcom/facebook/Session;.getExpirationDate:()Ljava/util/Date;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24da0>,
#  'Landroid/content/ComponentName;.<init>:(Ljava/lang/String;Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24dd8>,
#  'Landroid/content/Intent;.setComponent:(Landroid/content/ComponentName;)Landroid/content/Intent;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24e10>,
#  'Lcom/facebook/Session;.requestNewReadPermissions:(Lcom/facebook/Session$NewPermissionsRequest;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24e48>,
#  'Lcom/facebook/Session;.isPermissionGranted:(Ljava/lang/String;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24e80>,
#  'Lcom/facebook/widget/FacebookDialog;.canPresentShareDialog:(Landroid/content/Context;[Lcom/facebook/widget/FacebookDialog$ShareDialogFeature;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24eb8>,
#  'Landroid/content/pm/Signature;.toByteArray:()[B': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24ef0>,
#  'Ljava/security/MessageDigest;.update:([B)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24f28>,
#  'Landroid/util/Base64;.encodeToString:([BI)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24f60>,
#  'Landroid/app/AlertDialog;.setTitle:(Ljava/lang/CharSequence;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24f98>,
#  'Landroid/app/AlertDialog;.setMessage:(Ljava/lang/CharSequence;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f07a24fd0>,
#  'Landroid/content/pm/PackageManager$NameNotFoundException;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad048>,
#  'Ljava/security/NoSuchAlgorithmException;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad080>,
#  'Ljava/lang/Exception;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad0b8>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.<init>:(Landroid/content/Context;Lcom/facebook/Session;Landroid/os/Bundle;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad0f0>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.setOnCompleteListener:(Lcom/facebook/widget/WebDialog$OnCompleteListener;)Lcom/facebook/widget/WebDialog$BuilderBase;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad128>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.setMessage:(Ljava/lang/String;)Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad160>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.setTitle:(Ljava/lang/String;)Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad198>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.setTo:(Ljava/lang/String;)Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad1d0>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.setData:(Ljava/lang/String;)Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad208>,
#  'Lcom/facebook/widget/WebDialog$RequestsDialogBuilder;.build:()Lcom/facebook/widget/WebDialog;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad240>,
#  'Lorg/json/JSONStringer;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad278>,
#  'Lorg/json/JSONStringer;.object:()Lorg/json/JSONStringer;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad2b0>,
#  'Lorg/json/JSONStringer;.key:(Ljava/lang/String;)Lorg/json/JSONStringer;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad2e8>,
#  'Lorg/json/JSONStringer;.value:(Ljava/lang/Object;)Lorg/json/JSONStringer;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad320>,
#  'Lorg/json/JSONStringer;.endObject:()Lorg/json/JSONStringer;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad358>,
#  'Lorg/json/JSONStringer;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad390>,
#  'Landroid/os/Parcel;.readString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad3c8>,
#  'Landroid/os/Parcel;.readInt:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad400>,
#  'Landroid/os/Parcel;.writeString:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad438>,
#  'Landroid/os/Parcel;.writeInt:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad470>,
#  'Lcom/facebook/SessionState;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad4a8>,
#  'Ljava/lang/Exception;.getLocalizedMessage:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad4e0>,
#  'Lcom/facebook/FacebookRequestError;.getUserActionMessageId:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad518>,
#  'Landroid/app/Activity;.getString:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad550>,
#  'Lcom/facebook/SessionState;.ordinal:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad588>,
#  'Landroid/os/Handler;.handleMessage:(Landroid/os/Message;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad5c0>,
#  '[Lc/m/x/a/gpgam3/b;.clone:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad5f8>,
#  'Ljava/lang/Object;.notifyAll:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad630>,
#  'Ljava/io/Writer;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad668>,
#  'Ljava/lang/StringBuilder;.delete:(II)Ljava/lang/StringBuilder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad6a0>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdClosed:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad6d8>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdFailedToLoad:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad710>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdLeftApplication:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad748>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdLoaded:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad780>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdClicked:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad7b8>,
#  'Lcom/google/android/gms/ads/mediation/MediationBannerListener;.onAdOpened:(Lcom/google/android/gms/ads/mediation/MediationBannerAdapter;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad7f0>,
#  'Landroid/util/AndroidRuntimeException;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad828>,
#  'Ljava/lang/Object;.clone:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad860>,
#  '[I.clone:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad898>,
#  '[Ljava/lang/Object;.clone:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad8d0>,
#  'Lorg/json/JSONObject;.put:(Ljava/lang/String;I)Lorg/json/JSONObject;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad908>,
#  'Ljava/lang/Runtime;.getRuntime:()Ljava/lang/Runtime;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad940>,
#  'Ljava/lang/Runtime;.availableProcessors:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad978>,
#  'Ljava/util/concurrent/LinkedBlockingQueue;.<init>:(I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad9b0>,
#  'Ljava/util/concurrent/ThreadPoolExecutor;.<init>:(IIJLjava/util/concurrent/TimeUnit;Ljava/util/concurrent/BlockingQueue;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ad9e8>,
#  'Ljava/util/concurrent/ThreadPoolExecutor;.allowCoreThreadTimeOut:(Z)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ada20>,
#  'Landroid/text/TextUtils;.writeToParcel:(Ljava/lang/CharSequence;Landroid/os/Parcel;I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079ada58>,
#  'Landroid/os/Parcelable$Creator;.createFromParcel:(Landroid/os/Parcel;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ada90>,
#  'Landroid/app/Activity;.getPackageName:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adac8>,
#  'Landroid/app/Activity;.getSystemService:(Ljava/lang/String;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adb00>,
#  'Landroid/app/AlertDialog$Builder;.<init>:(Landroid/content/Context;I)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079adb38>,
#  'Landroid/app/Activity;.getSharedPreferences:(Ljava/lang/String;I)Landroid/content/SharedPreferences;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adb70>,
#  'Landroid/widget/FrameLayout;.<init>:(Landroid/content/Context;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079adba8>,
#  'Landroid/view/View;.getContext:()Landroid/content/Context;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adbe0>,
#  'Landroid/view/View;.getLayoutParams:()Landroid/view/ViewGroup$LayoutParams;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adc18>,
#  'Landroid/widget/FrameLayout$LayoutParams;.<init>:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079adc50>,
#  'Landroid/view/View;.setLayoutParams:(Landroid/view/ViewGroup$LayoutParams;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079adc88>,
#  'Lcom/facebook/Response;.getConnection:()Ljava/net/HttpURLConnection;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adcc0>,
#  'Ljava/net/HttpURLConnection;.getURL:()Ljava/net/URL;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adcf8>,
#  'Ljava/net/URL;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079add30>,
#  'Lorg/json/JSONArray;.toString:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079add68>,
#  'Lcom/adobe/fre/FREContext;.getActivity:()Landroid/app/Activity;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adda0>,
#  'Ljava/lang/Class;.getDeclaredClasses:()[Ljava/lang/Class;': <gensim.models.keyedvectors.Vocab at 0x7f3f079addd8>,
#  'Ljava/lang/reflect/Proxy;.newProxyInstance:(Ljava/lang/ClassLoader;[Ljava/lang/Class;Ljava/lang/reflect/InvocationHandler;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ade10>,
#  'Ljava/lang/Class;.getMethods:()[Ljava/lang/reflect/Method;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ade48>,
#  'Landroid/content/Context;.getMainLooper:()Landroid/os/Looper;': <gensim.models.keyedvectors.Vocab at 0x7f3f079ade80>,
#  'Landroid/content/Intent;.getAction:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adeb8>,
#  'Landroid/content/Intent;.resolveTypeIfNeeded:(Landroid/content/ContentResolver;)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adef0>,
#  'Landroid/content/Intent;.getData:()Landroid/net/Uri;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adf28>,
#  'Landroid/content/Intent;.getScheme:()Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adf60>,
#  'Landroid/content/Intent;.getCategories:()Ljava/util/Set;': <gensim.models.keyedvectors.Vocab at 0x7f3f079adf98>,
#  'Landroid/content/Intent;.getFlags:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079adfd0>,
#  'Landroid/content/IntentFilter;.match:(Ljava/lang/String;Ljava/lang/String;Ljava/lang/String;Landroid/net/Uri;Ljava/util/Set;Ljava/lang/String;)I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb048>,
#  'Ljava/util/HashMap;.remove:(Ljava/lang/Object;)Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb080>,
#  'Landroid/content/IntentFilter;.countActions:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb0b8>,
#  'Landroid/content/IntentFilter;.getAction:(I)Ljava/lang/String;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb0f0>,
#  'Landroid/content/BroadcastReceiver;.onReceive:(Landroid/content/Context;Landroid/content/Intent;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb128>,
#  'Lcom/adobe/fre/FREContext;.dispatchStatusEventAsync:(Ljava/lang/String;Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb160>,
#  'Ljava/lang/Exception;.<init>:(Ljava/lang/String;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb198>,
#  'Ljava/lang/ThreadLocal;.get:()Ljava/lang/Object;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb1d0>,
#  'Ljava/lang/ThreadLocal;.remove:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb208>,
#  'Ljava/lang/ThreadLocal;.set:(Ljava/lang/Object;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb240>,
#  'Ljava/util/concurrent/ExecutorService;.execute:(Ljava/lang/Runnable;)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb278>,
#  'Ljava/lang/ThreadLocal;.<init>:()V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb2b0>,
#  'Lcom/facebook/SessionState;.values:()[Lcom/facebook/SessionState;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb2e8>,
#  'Lcom/google/android/gms/ads/AdSize;.<init>:(II)V': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb320>,
#  'Lcom/google/android/gms/ads/AdSize;.b:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb358>,
#  'Lcom/google/android/gms/ads/AdSize;.a:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb390>,
#  'Lcom/google/android/gms/ads/AdSize;.equals:(Ljava/lang/Object;)Z': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb3c8>,
#  'Lcom/google/android/gms/ads/AdSize;.hashCode:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb400>,
#  'Lcom/google/android/gms/ads/mediation/MediationAdRequest;.getBirthday:()Ljava/util/Date;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb438>,
#  'Lcom/google/android/gms/ads/AdRequest$Builder;.a:(Ljava/util/Date;)Lcom/google/android/gms/ads/AdRequest$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb470>,
#  'Lcom/google/android/gms/ads/mediation/MediationAdRequest;.getGender:()I': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb4a8>,
#  'Lcom/google/android/gms/ads/AdRequest$Builder;.a:(I)Lcom/google/android/gms/ads/AdRequest$Builder;': <gensim.models.keyedvectors.Vocab at 0x7f3f079bb4e0>,
#  ...}

# %%
model.wv['Ljava/lang/String;.<init>:([BIILjava/lang/String;)V']
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# memmap([ 0.7027573 ,  0.2357014 ,  0.50791395,  0.5066296 , -0.07097847,
#         -0.89561117,  0.4107526 ,  0.5397846 ,  0.29125744,  0.80521417,
#          0.07104103, -0.20695022,  0.4575843 , -0.45108658, -0.05520138,
#          0.82249326, -0.54668325,  0.58708084,  0.05244777, -0.9105996 ,
#          0.33870474,  0.06001737, -0.10135366, -0.10188413,  0.44558525,
#         -0.23854348, -0.18795718,  0.39265135, -0.03374079, -0.44190425,
#         -0.5278169 , -0.13389234,  0.17642395, -0.8558    ,  0.28307894,
#         -0.5883036 ,  0.44654626,  0.68218887, -0.6389782 ,  0.08484074,
#          0.6812076 , -0.5540381 ,  1.2570051 ,  0.568323  , -0.19316052,
#         -0.18834612,  0.16485605,  0.15295045,  0.2568722 , -0.40117458,
#          0.19130266,  0.32208824], dtype=float32)

# %% [markdown]
# # #Now prepare the Train-data for K-fold cross validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
batch_size = 300

# %% [markdown]
# ###Prepare the machine learning model here too, we will feed the data to this model using skfold after createing the model

# %%
# Training Parameters
learning_rate = 0.001
training_steps = 500
              #means there are 84 batches in an epoch with each batch having 150 apps 
total_epochs = 20
display_step = 200
# Network Parameters
num_input = 52 # MNIST data input (img shape: 28*28)
timesteps = 4000 # timesteps
num_hidden = 128 # hidden layer num of features
num_classes = 2 # Binary classification
# tf Graph input
tf.reset_default_graph()
with tf.name_scope("placeholders"):
    xin = tf.placeholder("float", [None, timesteps, num_input],name="xin")
    Y = tf.placeholder("float", [None, num_classes],name="Y")
with tf.name_scope("weights"):
    weights = {    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))}
with tf.name_scope("bias"):
    biases = {    'out': tf.Variable(tf.random_normal([num_classes]))}
def RNN(xin, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    xin = tf.unstack(xin, timesteps, 1) #xin = tf.unstack(xin, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, xin, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
from tensorflow.contrib import rnn
with tf.name_scope("RNN"):
    logits = RNN(xin, weights, biases)
with tf.name_scope("Softmax"):
    prediction = tf.nn.softmax(logits)
# Define loss and optimizer
with tf.name_scope("Lossmeasure"):
    loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))
with tf.name_scope("Optimizer"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
    train_op = optimizer.minimize(loss_op)
# Out:
# WARNING:tensorflow:From <ipython-input-29-74551da22c08>:31: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# WARNING:tensorflow:From <ipython-input-30-42d4c0ea5db2>:8: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# Evaluate model (with test logits, for dropout to be disabled)
with tf.name_scope("evaluation"):
    correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
with tf.name_scope("Accuracy"):
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
loss_summary = tf.summary.scalar('LOSS',loss_op)
accuracy_summary = tf.summary.scalar('Accuracy',accuracy)

# %%
file_writer = tf.summary.FileWriter(logdir,tf.get_default_graph())
init = tf.global_variables_initializer()

# %%
batch_num_for_graph=0
def run_train(session,which_fold,X_train,y_train):
    print ("Start Training")
    session.run(init)
    global batch_num_for_graph
    merged = tf.summary.merge_all()
    epoch_accuracy=[]
    epoch_loss=[]
    for epoch in range (3):
        batch_accuracy=[]
        batch_loss=[]
        
        #total_batch = int(len(X_train)/batch_size)
        total_batch=2
        for i in range (total_batch):
            #now prepare data for each batch
            
            batch_x = X_train[i*batch_size:(i+1)*batch_size]
            batch_y = y_train[i*batch_size:(i+1)*batch_size]
            #now we have the relevant filenames only
            batch_y = make_label(batch_y)
            sentences, _ = read_data("/home/ubuntu/Static/",batch_x)
            #print("read data")
            #nwo we need to convert sentences to word-embedded features and then we are ready to train
            batch_x = get_embedding(sentences)
            #print("got embedding")
            # Reshape data to get 28 seq of 28 elements
            batch_x = batch_x.reshape((batch_size,timesteps,num_input))
            # Run optimization op (backprop)
            loss,acc,summary,_ = session.run([loss_op,accuracy,merged,train_op], feed_dict={xin:batch_x,Y:batch_y})
            batch_accuracy.append(acc)
            batch_loss.append(loss)
            if  i==(batch_size-1) or (i==0 and which_fold==1) :
            
                # Calculate batch loss and accuracy
                #summary_str = loss_summary.eval(session=sess,feed_dict={xin: batch_x,Y: batch_y})
                #loss, acc,summary = session.run([loss_op,accuracy,merged],feed_dict={xin: batch_x,Y: batch_y})
                #file_writer.add_summary(summary,(epoch+which_fold+i)*batch_size)
                print("benign  = "+str(batch_y[:,0].sum()) + "  malicious = "+str(batch_y[:,1].sum()))
                print("Fold " + str(which_fold) + " Epoch "+str(epoch)+",Minibatch Loss= " + \
                      "{:.4f}".format(loss) + ", Training Accuracy= " + \
                      "{:.3f}".format(acc))  
        epoch_accuracy.append(np.mean(batch_accuracy))
        epoch_loss.append(np.mean(batch_loss))
        summary = tf.Summary()
        summary.value.add(tag="Batch Accuracy", simple_value=np.mean(batch_accuracy))
        summary.value.add(tag="Batch Loss",simple_value=np.mean(batch_loss))
        file_writer.add_summary(summary, batch_num_for_graph)
        batch_num_for_graph+=1
    return np.mean(epoch_accuracy), np.mean(epoch_loss)
                # Create a new Summary object with your measure
                #summary = tf.Summary()
                #summary.value.add(tag="%s Batch Accuracy" %step, simple_value=batch_acc)
                #summary.value.add(tag="%s Batch Loss" %step, simple_value=batch_ls)
                # Add it to the Tensorboard summary writer
                # Make sure to specify a step parameter to get nice graphs over time
                #file_writer.add_summary(summary, count)
                #file_writer.add_summary(accuracy_summary_str,step)
    #             summary = tf_session.run(tf.summary.merge_all())
                #file_writer.add_summary(summary_str, step)
                #loss, acc = sess.run([loss_op, accuracy], feed_dict={xin: batch_x,Y: batch_y})

# %%
def run_validation_or_test(session,X_train,y_train):
    batch_accuracy=[]
    batch_loss=[]
    #total_batch = int(len(X_train)/batch_size)
    total_batch=2
    for i in range (total_batch):
        batch_x = X_train[i*batch_size:(i+1)*batch_size]
        batch_y = y_train[i*batch_size:(i+1)*batch_size]
        #now we have the relevant filenames only
        batch_y = make_label(batch_y)
        sentences, _ = read_data("/home/ubuntu/Static/",batch_x)
        #print("read data")
        #nwo we need to convert sentences to word-embedded features and then we are ready to train
        batch_x = get_embedding(sentences)
        #print("got embedding")
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size,timesteps,num_input))
        # Run optimization op (backprop)
        loss,acc = session.run([loss_op,accuracy],feed_dict={xin: batch_x,Y: batch_y})
        print("Accuracy-acc = " +str(acc) + "benign  = "+str(batch_y[:,0].sum()) + "  malicious = "+str(batch_y[:,1].sum()))
        batch_accuracy.append(acc)
        batch_loss.append(loss)
    return np.mean(batch_accuracy), np.mean(batch_loss)

# %%
def read_data(foldername,fileslist):
    sentences=[]
    numwords=[]
    for fname in fileslist:
        with open(os.path.join(foldername, fname)) as f:
            content = f.read().strip()
            content = re.sub(r"[\n#]","",content).split(" ")
            counter = len(content)
            numwords.append(counter)   #only consider the 4000 APIs# talk and decide later// part of tuning
        sentences.append(content[:4000])
        
    return sentences,numwords

def make_label(val):
    
    d = np.zeros((val.size,2))
    i = 0;
    for item in val:
        if item==0: #if benign
            d[i][0]=1.0
        else:
            d[i][1]=1.0
        i+=1
    return d
def get_embedding(sentences):
    d = np.zeros((len(sentences),4000,52))
    i=0
    for sentence in sentences:
        j=0
        for word in sentence:
            d[i][j]= model.wv[word]
            j+=1
        i+=1
    return d

# %%
def cross_validate(session,split_size=5):
    results=[]
    validation_num=0
    skf = StratifiedKFold(n_splits=split_size,shuffle=True,random_state=42)
    per_kminus1_fold_train_accuracy=[]
    per_kminus1_fold_train_loss=[]
    which_fold=1
    for train_index, test_index in skf.split(strat_train_set['apk'].tolist(),strat_train_set['label'].tolist()):
        train = strat_train_set.loc[train_index]
        print(len(train_index))
        print(len(test_index))
        test = strat_train_set.loc[test_index]
        X_train = train['apk']  #training data features; currently just filenames
        X_test = test['apk']   
        y_train = train['label']  #training data label
        y_test = test['label']
       
        #now run the train
        epoch_acc, epoch_loss = run_train(session,which_fold,X_train,y_train)
        print("trained a fold %s " %which_fold)
        per_kminus1_fold_train_accuracy.append(epoch_acc)
        per_kminus1_fold_train_loss.append(epoch_loss)
        which_fold+=1
        #now obtian validation testing data usign the filenames
        
        acc,loss = run_validation_or_test(session,X_test,y_test)
        print("Overall Accuracy -for the fold "+ str(acc)+" loss = "+str(loss))    
        summary = tf.Summary()
        summary.value.add(tag="Validation Accuracy", simple_value=acc)
        summary.value.add(tag="Validation loss", simple_value=loss)
       
        # Add it to the Tensorboard summary writer
        # Make sure to specify a step parameter to get nice graphs over time
        file_writer.add_summary(summary, validation_num)
        validation_num+=1
        results.append(acc)
    return results,per_kminus1_fold_train_accuracy,per_kminus1_fold_train_loss

# %%
with tf.Session() as session:
    result,per_fold_accuracy,per_fold_loss = cross_validate(session,5)
    print ("Cross validation result: %s" %result)
    X_test = strat_test_set['apk']
    y_test = strat_test_set['label']
#     sentences, _ = read_data("/home/ubuntu/Static/",X_test)
#     labels = make_label(y_test)
    #nwo we need to convert sentences to word-embedded features and then we are ready to TEST on validation
#     embedded_sentences = get_embedding(sentences)
    #now run the FINAL TEST
    acc,loss = run_validation_or_test(session,X_test,y_test)
    print("Overall Accuracy -for the fold "+ str(acc)+" loss = "+str(loss)) 
    #print ("Test Accuracy %f"% session.run(accuracy,feed_dict={xin: embedded_sentences,Y: labels}))
# Out:
# 30752
# 7688
# Start Training
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# benign  = 223.0  malicious = 77.0
# Fold 1 Epoch 0,Minibatch Loss= 1.3233, Training Accuracy= 0.350
# benign  = 223.0  malicious = 77.0
# Fold 1 Epoch 1,Minibatch Loss= 1.0470, Training Accuracy= 0.460
# benign  = 223.0  malicious = 77.0
# Fold 1 Epoch 2,Minibatch Loss= 0.8939, Training Accuracy= 0.497
# trained a fold 1
# Accuracy-acc = 0.49333334benign  = 222.0  malicious = 78.0
# Accuracy-acc = 0.48333332benign  = 220.0  malicious = 80.0
# Overall Accuracy -for the fold 0.48833334 loss = 0.86045444
# 30752
# 7688
# Start Training
# trained a fold 2
# Accuracy-acc = 0.42benign  = 224.0  malicious = 76.0
# Accuracy-acc = 0.51benign  = 220.0  malicious = 80.0
# Overall Accuracy -for the fold 0.46499997 loss = 0.7365248
# 30752
# 7688
# Start Training
# trained a fold 3
# Accuracy-acc = 0.76666665benign  = 235.0  malicious = 65.0
# Accuracy-acc = 0.74666667benign  = 226.0  malicious = 74.0
# Overall Accuracy -for the fold 0.75666666 loss = 0.5395248
# 30752
# 7688
# Start Training
# trained a fold 4
# Accuracy-acc = 0.27benign  = 245.0  malicious = 55.0
# Accuracy-acc = 0.32333332benign  = 222.0  malicious = 78.0
# Overall Accuracy -for the fold 0.29666668 loss = 1.1620557
# 30752
# 7688
# Start Training
# trained a fold 5
# Accuracy-acc = 0.44666666benign  = 232.0  malicious = 68.0
# Accuracy-acc = 0.47666666benign  = 226.0  malicious = 74.0
# Overall Accuracy -for the fold 0.46166664 loss = 0.7565441
# Cross validation result: [0.48833334, 0.46499997, 0.75666666, 0.29666668, 0.46166664]
# Accuracy-acc = 0.45333335benign  = 221.0  malicious = 79.0
# Accuracy-acc = 0.4benign  = 233.0  malicious = 67.0
# Overall Accuracy -for the fold 0.42666668 loss = 0.80524594

# %%
import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)

# %%
# for train_index, test_index in skf.split(strat_train_set['apk'].tolist(),strat_train_set['label'].tolist()):
#     train = strat_train_set.loc[train_index]
#     test = strat_train_set.loc[test_index]
#     X_train = train['apk']
#     X_test = test['apk']
#     y_train = train['label']
#     y_test = test['label']
#     #print(train[:10])
#     print(len(train))
#     print(len(X_train))
#     print(len(X_test))

# %%
# filesnameonly = fileslistwithlabel['apk'].tolist()
# labelsonly = fileslistwithlabel['label'].tolist()

# %%
# def simple_zip(batch_size=10):
#     dx = tf.data.Dataset.from_tensor_slices(filesnameonly)
#     dy = tf.data.Dataset.from_tensor_slices(labelsonly)
#     dcomb = tf.data.Dataset.zip((dx,dy)).repeat().batch(batch_size)
#     iterator = dcomb.make_initializable_iterator()
#     next_element = iterator.get_next()
#     with tf.Session() as sess:
#         sess.run(iterator.initializer)
#         for i in range(2):
#             val = sess.run(next_element)
#             print(val)

# %%
# simple_zip(2)
